# %%
# ── BLOQUE 1: PREPROCESAMIENTO ESTÁTICO Y GUARDADO ─────────────────────────────────

import pickle
import pandas as pd
import math
import requests
import random
from datetime import datetime, timedelta
from filtros_df import filter_labors_by_date, filter_labors_by_city

# — Parámetros —————————————————————————————————————————————————————————————
ITERATIONS              = 5
ALPHA                   = 1
SEED                    = 10
DISTANCE_METHOD         = 'Manhattan'
alfred_speed            = 30   # km/h para conductor hacia primer punto
vehicle_transport_speed = 40   # km/h para transporte de vehículo
tiempo_previo           = 30   # minutos antes del schedule_date
tiempo_gracia           = 15
tiempo_alistar          = 15
tiempo_other            = 30
tiempo_finalizacion     = 15

random.seed(SEED)

# — Cargar distancias precalculadas ——————————————————————————————————————————
with open('distances.pkl', 'rb') as f:
    DIST_DICT = pickle.load(f)

# — Cargar datos base ———————————————————————————————————————————————————————
directorio_df = pd.read_csv("Datos/Procesados/directorio_df.csv")
df_dist       = pd.read_pickle("df_dist.pkl")

# — 0) Filtrado y mix automático de días en base_day ———————————————————————————
start_date = "2023-01-02"
end_date   = "2023-01-03"

# Filtrado por ciudad (Bogotá=149) y por rango de fechas
df_bogota = filter_labors_by_city(df_dist, 149)
df_dia    = filter_labors_by_date(df_bogota, start_date=start_date, end_date=end_date)
df_dia    = df_dia.query("state_service!='CANCELED'") \
                 .sort_values(['service_id','labor_start_date']) \
                 .reset_index(drop=True)

# — 0.2) Remapeo fechas a base_day ————————————————————————————————————————
base_day = pd.to_datetime(start_date).date()
def remap_to_base(dt):
    if pd.isna(dt): return dt
    delta = (base_day - dt.date()).days
    return dt + timedelta(days=delta)

for c in ['schedule_date','labor_start_date','labor_end_date']:
    df_dia[c] = df_dia[c].apply(remap_to_base)

# — 0.3) Construir services_map_df ————————————————————————————————————————
map_src = df_dia[[
    'service_id','labor_id','labor_category',
    'start_address_point','end_address_point','address_point',
    'labor_start_date'
]].sort_values(['service_id','labor_start_date']).reset_index(drop=True)

rows = []
for svc, grp in map_src.groupby('service_id', sort=False):
    n    = len(grp)
    idxs = grp.index.tolist()
    for i, idx in enumerate(idxs):
        r = grp.loc[idx]
        if n == 1:
            sp, ep = r['start_address_point'], r['end_address_point']
        else:
            if r['labor_category']=='VEHICLE_TRANSPORTATION':
                sp = r['start_address_point']
                ep = grp.iloc[i+1]['end_address_point'] if i<n-1 else r['end_address_point']
            else:
                sp = ep = r['address_point']
        rows.append({
            'service_id':      svc,
            'labor_id':        r['labor_id'],
            'map_start_point': sp,
            'map_end_point':   ep
        })
services_map_df = pd.DataFrame(rows)
services_map_df['labor_id'] = services_map_df['labor_id'].astype(df_dia['labor_id'].dtype)

# — 1) Funciones auxiliares: parse_point, distance —————————————————————————————
def parse_point(s):
    if pd.isna(s) or not s.strip().startswith("POINT"): return None, None
    lon, lat = map(float, s.lstrip('POINT').strip(' ()').split())
    return lat, lon

OSRM_URL = "http://router.project-osrm.org/route/v1/driving/"
def distance(p1, p2, method='haversine', timeout=5):
    if method=='precalced':
        return DIST_DICT.get((p1,p2), float('nan'))
    lat1, lon1 = parse_point(p1)
    lat2, lon2 = parse_point(p2)
    if None in (lat1,lon1,lat2,lon2): return float('nan')
    if method=='haversine':
        φ1,φ2 = map(math.radians,(lat1,lat2))
        dφ    = math.radians(lat2-lat1)
        dλ    = math.radians(lon2-lon1)
        a     = math.sin(dφ/2)**2 + math.cos(φ1)*math.cos(φ2)*math.sin(dλ/2)**2
        return 2*6371*math.atan2(math.sqrt(a), math.sqrt(1-a))
    if method=='osrm':
        coords = f"{lon1},{lat1};{lon2},{lat2}"
        try:
            r = requests.get(OSRM_URL+coords+"?overview=false", timeout=timeout)
            r.raise_for_status()
            return r.json()['routes'][0]['distance']/1000
        except:
            return distance(p1,p2,method='haversine')
    # Manhattan
    KM_PER_DEG_LAT = 111.32
    mean_lat = math.radians((lat1+lat2)/2)
    dlat = abs(lat1-lat2)*KM_PER_DEG_LAT
    dlon = abs(lon1-lon2)*KM_PER_DEG_LAT*math.cos(mean_lat)
    return dlat + dlon

# — 2) process_group (con corrección para A_idx vacío) —————————————————————————
def process_group(grp):
    # si sólo tiene 1 labor, la dejamos si es VEHICLE_TRANSPORTATION
    if len(grp)==1:
        return grp if grp.iloc[0]['labor_category']=='VEHICLE_TRANSPORTATION' else grp.iloc[0:0]

    A_idx = list(grp.index[grp['labor_category']=='VEHICLE_TRANSPORTATION'])
    # nueva línea: si no hay ninguna VEHICLE_TRANSPORTATION, descartamos el servicio
    if not A_idx:
        return grp.iloc[0:0]

    B_idx = [i for i in grp.index[grp['labor_category']!='VEHICLE_TRANSPORTATION']
             if pd.notna(grp.at[i,'shop']) and pd.notna(grp.at[i,'address_point'])]
    if not B_idx:
        return grp.iloc[0:0]

    inits   = [i for i in A_idx if grp.at[i,'labor_name']=='Alfred Initial Transport']
    firstA  = inits[0] if inits else A_idx[0]
    A_rem   = [i for i in A_idx if i!=firstA]

    start_pt = grp['start_address_point'].iloc[0]
    dist_map = {i: distance(start_pt, grp.at[i,'address_point']) for i in B_idx}
    B_sorted = sorted(B_idx, key=lambda i: dist_map[i])[:len(A_idx)-1]

    A_rem_sorted = sorted(A_rem, key=lambda i: grp.at[i,'labor_start_date'])
    needed_A     = [firstA] + A_rem_sorted[:len(B_sorted)]

    final = []
    for j, b in enumerate(B_sorted):
        final += [needed_A[j], b]
    final.append(needed_A[-1])

    return grp.loc[final]

# — 3) Construir df_cleaned_template y merge con map points ——————————————————————
cleaned = []
for svc, grp in df_dia.groupby('service_id', sort=False):
    pg = process_group(grp)
    if not pg.empty:
        cleaned.append(pg)
df_cleaned_template = (
    pd.concat(cleaned, ignore_index=True)
      .merge(services_map_df, on=['service_id','labor_id'], how='left')
)

# — 4) avg_times_map de df_dist —————————————————————————————————————————————
df_temp = (
    df_dist
      .dropna(subset=['labor_start_date','labor_end_date'])
      .assign(duration_td=lambda d: d['labor_end_date']-d['labor_start_date'])
)
df_temp = df_temp[df_temp['duration_td']<=pd.Timedelta(days=1)]
df_temp['duration_min'] = df_temp['duration_td'].dt.total_seconds()/60
avg_times_map = df_temp.groupby('labor_name')['duration_min'].mean().to_dict()

# — 5) Guardar plantilla para BLOQUE 2 ——————————————————————————————————————
df_cleaned_template.to_pickle('cleaned_static_template.pkl')
print("✅ BLOQUE 1 completado: plantilla estática guardada en 'cleaned_static_template.pkl'")




df_cleaned_template['day'] = df_cleaned_template['schedule_date'].dt.date

# 3) Agrupar por día y contar número de labors
daily_counts = (
    df_cleaned_template
      .groupby('day')
      .size()
      .reset_index(name='num_labors')
      .sort_values('num_labors', ascending=False)
      .reset_index(drop=True)
)

# 4) Mostrar resultados
print("Días con más labors (después de procesar Bloque 1):")
print(daily_counts)
# Out:
# ✅ BLOQUE 1 completado: plantilla estática guardada en 'cleaned_static_template.pkl'
# Días con más labors (después de procesar Bloque 1):
#           day  num_labors
# 0  2023-01-02          36

# %%
# ── BLOQUE 1: PREPROCESAMIENTO ESTÁTICO POR DÍA Y GUARDADO ────────────────────────────

import os
import pickle
import pandas as pd
import math
import requests
import random
from datetime import datetime, timedelta
from filtros_df import filter_labors_by_city

# — Parámetros —————————————————————————————————————————————————————————————
SEED                    = 10
DISTANCE_METHOD         = 'Manhattan'
alfred_speed            = 30   # km/h para conductor hacia primer punto
vehicle_transport_speed = 40   # km/h para transporte de vehículo
tiempo_previo           = 30   # minutos antes del schedule_date
tiempo_gracia           = 15
tiempo_alistar          = 15
tiempo_other            = 30
tiempo_finalizacion     = 15

random.seed(SEED)

# — Crear carpeta de salida ————————————————————————————————————————————————
os.makedirs("processed_by_date", exist_ok=True)

# — Cargar datos base —————————————————————————————————————————————————————
directorio_df = pd.read_csv("Datos/Procesados/directorio_df.csv")
df_raw        = pd.read_pickle("df_dist.pkl")

# — Cargar distancias precalculadas ——————————————————————————————————————————
with open('distances.pkl', 'rb') as f:
    DIST_DICT = pickle.load(f)

# — Funciones auxiliares —————————————————————————————————————————————————————————

def parse_point(s):
    if pd.isna(s) or not s.strip().startswith("POINT"):
        return None, None
    lon, lat = map(float, s.lstrip('POINT').strip(' ()').split())
    return lat, lon

OSRM_URL = "http://router.project-osrm.org/route/v1/driving/"
def distance(p1, p2, method='haversine', timeout=5):
    if method == 'precalced':
        return DIST_DICT.get((p1, p2), float('nan'))
    lat1, lon1 = parse_point(p1)
    lat2, lon2 = parse_point(p2)
    if None in (lat1, lon1, lat2, lon2):
        return float('nan')
    if method == 'haversine':
        φ1, φ2 = map(math.radians, (lat1, lat2))
        dφ = math.radians(lat2 - lat1)
        dλ = math.radians(lon2 - lon1)
        a = math.sin(dφ/2)**2 + math.cos(φ1)*math.cos(φ2)*math.sin(dλ/2)**2
        return 2 * 6371 * math.atan2(math.sqrt(a), math.sqrt(1 - a))
    if method == 'osrm':
        coords = f"{lon1},{lat1};{lon2},{lat2}"
        try:
            r = requests.get(OSRM_URL + coords + "?overview=false", timeout=timeout)
            r.raise_for_status()
            return r.json()['routes'][0]['distance'] / 1000
        except:
            return distance(p1, p2, method='haversine')
    # Manhattan
    KM_PER_DEG_LAT = 111.32
    mean_lat = math.radians((lat1 + lat2) / 2)
    dlat = abs(lat1 - lat2) * KM_PER_DEG_LAT
    dlon = abs(lon1 - lon2) * KM_PER_DEG_LAT * math.cos(mean_lat)
    return dlat + dlon

def process_group(grp):
    if len(grp) == 1:
        return grp if grp.iloc[0]['labor_category']=='VEHICLE_TRANSPORTATION' else grp.iloc[0:0]
    A_idx = list(grp.index[grp['labor_category']=='VEHICLE_TRANSPORTATION'])
    if not A_idx:
        return grp.iloc[0:0]
    B_idx = [i for i in grp.index[grp['labor_category']!='VEHICLE_TRANSPORTATION']
             if pd.notna(grp.at[i,'shop']) and pd.notna(grp.at[i,'address_point'])]
    if not B_idx:
        return grp.iloc[0:0]
    inits  = [i for i in A_idx if grp.at[i,'labor_name']=='Alfred Initial Transport']
    firstA = inits[0] if inits else A_idx[0]
    A_rem  = [i for i in A_idx if i!=firstA]
    start_pt = grp['start_address_point'].iloc[0]
    dist_map = {i: distance(start_pt, grp.at[i,'address_point']) for i in B_idx}
    B_sorted = sorted(B_idx, key=lambda i: dist_map[i])[:len(A_idx)-1]
    A_rem_sorted = sorted(A_rem, key=lambda i: grp.at[i,'labor_start_date'])
    needed_A     = [firstA] + A_rem_sorted[:len(B_sorted)]
    final = []
    for j, b in enumerate(B_sorted):
        final += [needed_A[j], b]
    final.append(needed_A[-1])
    return grp.loc[final]

# — avg_times_map (histórico de df_raw) ———————————————————————————————————————————
df_temp = (
    df_raw
      .dropna(subset=['labor_start_date','labor_end_date'])
      .assign(duration_td=lambda d: d['labor_end_date']-d['labor_start_date'])
)
df_temp = df_temp[df_temp['duration_td'] <= pd.Timedelta(days=1)]
df_temp['duration_min'] = df_temp['duration_td'].dt.total_seconds() / 60
avg_times_map = df_temp.groupby('labor_name')['duration_min'].mean().to_dict()

# — Prefiltrar por ciudad (Bogotá=149) —————————————————————————————————————————
df_bogota = filter_labors_by_city(df_raw, 149)

# — Lista de días únicos según schedule_date —————————————————————————————————————
unique_days = sorted(df_bogota['schedule_date'].dt.date.dropna().unique())

for day in unique_days:
    day_str = day.isoformat()
    print(f"Procesando día {day_str}…")

    # 0) filtro **directo** por schedule_date.date == day
    df_dia = df_bogota[df_bogota['schedule_date'].dt.date == day].copy()
    if df_dia.empty:
        print(f"  → Sin datos para {day_str}, saltando.")
        continue

    # 0.2) remapear fechas a base_day = day
    base_day = day
    def remap_to_base(dt):
        if pd.isna(dt): return dt
        delta = (base_day - dt.date()).days
        return dt + timedelta(days=delta)
    for c in ['schedule_date','labor_start_date','labor_end_date']:
        df_dia[c] = df_dia[c].apply(remap_to_base)

    # 0.3) construir services_map_df
    map_src = df_dia[[
        'service_id','labor_id','labor_category',
        'start_address_point','end_address_point','address_point',
        'labor_start_date'
    ]].sort_values(['service_id','labor_start_date']).reset_index(drop=True)

    rows = []
    for svc, grp in map_src.groupby('service_id', sort=False):
        n    = len(grp)
        idxs = grp.index.tolist()
        for i, idx in enumerate(idxs):
            r = grp.loc[idx]
            if n == 1:
                sp, ep = r['start_address_point'], r['end_address_point']
            else:
                if r['labor_category']=='VEHICLE_TRANSPORTATION':
                    sp = r['start_address_point']
                    ep = grp.iloc[i+1]['end_address_point'] if i<n-1 else r['end_address_point']
                else:
                    sp = ep = r['address_point']
            rows.append({
                'service_id':      svc,
                'labor_id':        r['labor_id'],
                'map_start_point': sp,
                'map_end_point':   ep
            })
    services_map_df = pd.DataFrame(rows)
    services_map_df['labor_id'] = services_map_df['labor_id'].astype(df_dia['labor_id'].dtype)

    # 3) generar plantilla limpia
    cleaned = []
    for svc, grp in df_dia.groupby('service_id', sort=False):
        pg = process_group(grp)
        if not pg.empty:
            cleaned.append(pg)

    # — NUEVO CHEQUEO: si tras process_group no quedó nada, saltamos —
    if not cleaned:
        print(f"  → No servicios válidos para {day_str}, saltando.")
        continue

    df_cleaned_template = (
        pd.concat(cleaned, ignore_index=True)
          .merge(services_map_df, on=['service_id','labor_id'], how='left')
    )

    # 4) guardar plantilla por día
    out_path = f"processed_by_date/cleaned_static_template_{day_str}.pkl"
    df_cleaned_template.to_pickle(out_path)
    print(f"  → guardado: {out_path}")

print("✅ BLOQUE 1 completado para todos los días.")
# Out:
# Procesando día 2023-01-02…
#   → guardado: processed_by_date/cleaned_static_template_2023-01-02.pkl
# Procesando día 2023-01-03…
#   → guardado: processed_by_date/cleaned_static_template_2023-01-03.pkl
# Procesando día 2023-01-04…
#   → guardado: processed_by_date/cleaned_static_template_2023-01-04.pkl
# Procesando día 2023-01-05…
#   → guardado: processed_by_date/cleaned_static_template_2023-01-05.pkl
# Procesando día 2023-01-06…
#   → guardado: processed_by_date/cleaned_static_template_2023-01-06.pkl
# Procesando día 2023-01-07…
#   → guardado: processed_by_date/cleaned_static_template_2023-01-07.pkl
# Procesando día 2023-01-10…
#   → guardado: processed_by_date/cleaned_static_template_2023-01-10.pkl
# Procesando día 2023-01-11…
#   → guardado: processed_by_date/cleaned_static_template_2023-01-11.pkl
# Procesando día 2023-01-12…
#   → guardado: processed_by_date/cleaned_static_template_2023-01-12.pkl
# Procesando día 2023-01-13…
#   → guardado: processed_by_date/cleaned_static_template_2023-01-13.pkl
# Procesando día 2023-01-14…
#   → guardado: processed_by_date/cleaned_static_template_2023-01-14.pkl
# Procesando día 2023-01-16…
#   → guardado: processed_by_date/cleaned_static_template_2023-01-16.pkl
# Procesando día 2023-01-17…
#   → guardado: processed_by_date/cleaned_static_template_2023-01-17.pkl
# Procesando día 2023-01-18…
#   → guardado: processed_by_date/cleaned_static_template_2023-01-18.pkl
# Procesando día 2023-01-19…
#   → guardado: processed_by_date/cleaned_static_template_2023-01-19.pkl
# Procesando día 2023-01-20…
#   → guardado: processed_by_date/cleaned_static_template_2023-01-20.pkl
# Procesando día 2023-01-21…
#   → guardado: processed_by_date/cleaned_static_template_2023-01-21.pkl
# Procesando día 2023-01-23…
#   → guardado: processed_by_date/cleaned_static_template_2023-01-23.pkl
# Procesando día 2023-01-24…
#   → guardado: processed_by_date/cleaned_static_template_2023-01-24.pkl
# Procesando día 2023-01-25…
#   → guardado: processed_by_date/cleaned_static_template_2023-01-25.pkl
# Procesando día 2023-01-26…
#   → guardado: processed_by_date/cleaned_static_template_2023-01-26.pkl
# Procesando día 2023-01-27…
#   → guardado: processed_by_date/cleaned_static_template_2023-01-27.pkl
# Procesando día 2023-01-28…
#   → guardado: processed_by_date/cleaned_static_template_2023-01-28.pkl
# Procesando día 2023-01-30…
#   → guardado: processed_by_date/cleaned_static_template_2023-01-30.pkl
# Procesando día 2023-01-31…
#   → guardado: processed_by_date/cleaned_static_template_2023-01-31.pkl
# Procesando día 2023-02-01…
#   → guardado: processed_by_date/cleaned_static_template_2023-02-01.pkl
# Procesando día 2023-02-02…
#   → guardado: processed_by_date/cleaned_static_template_2023-02-02.pkl
# Procesando día 2023-02-03…
#   → guardado: processed_by_date/cleaned_static_template_2023-02-03.pkl
# Procesando día 2023-02-04…
#   → guardado: processed_by_date/cleaned_static_template_2023-02-04.pkl
# Procesando día 2023-02-06…
#   → guardado: processed_by_date/cleaned_static_template_2023-02-06.pkl
# Procesando día 2023-02-07…
#   → guardado: processed_by_date/cleaned_static_template_2023-02-07.pkl
# Procesando día 2023-02-08…
#   → guardado: processed_by_date/cleaned_static_template_2023-02-08.pkl
# Procesando día 2023-02-09…
#   → guardado: processed_by_date/cleaned_static_template_2023-02-09.pkl
# Procesando día 2023-02-10…
#   → guardado: processed_by_date/cleaned_static_template_2023-02-10.pkl
# Procesando día 2023-02-11…
#   → guardado: processed_by_date/cleaned_static_template_2023-02-11.pkl
# Procesando día 2023-02-13…
#   → guardado: processed_by_date/cleaned_static_template_2023-02-13.pkl
# Procesando día 2023-02-14…
#   → guardado: processed_by_date/cleaned_static_template_2023-02-14.pkl
# Procesando día 2023-02-15…
#   → guardado: processed_by_date/cleaned_static_template_2023-02-15.pkl
# Procesando día 2023-02-16…
#   → guardado: processed_by_date/cleaned_static_template_2023-02-16.pkl
# Procesando día 2023-02-17…
#   → guardado: processed_by_date/cleaned_static_template_2023-02-17.pkl
# Procesando día 2023-02-18…
#   → guardado: processed_by_date/cleaned_static_template_2023-02-18.pkl
# Procesando día 2023-02-20…
#   → guardado: processed_by_date/cleaned_static_template_2023-02-20.pkl
# Procesando día 2023-02-21…
#   → guardado: processed_by_date/cleaned_static_template_2023-02-21.pkl
# Procesando día 2023-02-22…
#   → guardado: processed_by_date/cleaned_static_template_2023-02-22.pkl
# Procesando día 2023-02-23…
#   → guardado: processed_by_date/cleaned_static_template_2023-02-23.pkl
# Procesando día 2023-02-24…
#   → guardado: processed_by_date/cleaned_static_template_2023-02-24.pkl
# Procesando día 2023-02-25…
#   → guardado: processed_by_date/cleaned_static_template_2023-02-25.pkl
# Procesando día 2023-02-27…
#   → guardado: processed_by_date/cleaned_static_template_2023-02-27.pkl
# Procesando día 2023-02-28…
#   → guardado: processed_by_date/cleaned_static_template_2023-02-28.pkl
# Procesando día 2023-03-01…
#   → guardado: processed_by_date/cleaned_static_template_2023-03-01.pkl
# Procesando día 2023-03-02…
#   → guardado: processed_by_date/cleaned_static_template_2023-03-02.pkl
# Procesando día 2023-03-03…
#   → guardado: processed_by_date/cleaned_static_template_2023-03-03.pkl
# Procesando día 2023-03-04…
#   → guardado: processed_by_date/cleaned_static_template_2023-03-04.pkl
# Procesando día 2023-03-06…
#   → guardado: processed_by_date/cleaned_static_template_2023-03-06.pkl
# Procesando día 2023-03-07…
#   → guardado: processed_by_date/cleaned_static_template_2023-03

#   → guardado: processed_by_date/cleaned_static_template_2024-04-29.pkl
# Procesando día 2024-04-30…
#   → guardado: processed_by_date/cleaned_static_template_2024-04-30.pkl
# Procesando día 2024-05-01…
#   → No servicios válidos para 2024-05-01, saltando.
# Procesando día 2024-05-02…
#   → guardado: processed_by_date/cleaned_static_template_2024-05-02.pkl
# Procesando día 2024-05-03…
#   → guardado: processed_by_date/cleaned_static_template_2024-05-03.pkl
# Procesando día 2024-05-04…
#   → guardado: processed_by_date/cleaned_static_template_2024-05-04.pkl
# Procesando día 2024-05-05…
#   → No servicios válidos para 2024-05-05, saltando.
# Procesando día 2024-05-06…
#   → guardado: processed_by_date/cleaned_static_template_2024-05-06.pkl
# Procesando día 2024-05-07…
#   → guardado: processed_by_date/cleaned_static_template_2024-05-07.pkl
# Procesando día 2024-05-08…
#   → guardado: processed_by_date/cleaned_static_template_2024-05-08.pkl
# Procesando día 2024-05-09…
#   → guardado: processed_by_date/cleaned_static_template_2024-05-09.pkl
# Procesando día 2024-05-10…
#   → guardado: processed_by_date/cleaned_static_template_2024-05-10.pkl
# Procesando día 2024-05-11…
#   → guardado: processed_by_date/cleaned_static_template_2024-05-11.pkl
# Procesando día 2024-05-12…
#   → No servicios válidos para 2024-05-12, saltando.
# Procesando día 2024-05-13…
#   → No servicios válidos para 2024-05-13, saltando.
# Procesando día 2024-05-14…
#   → guardado: processed_by_date/cleaned_static_template_2024-05-14.pkl
# Procesando día 2024-05-15…
#   → guardado: processed_by_date/cleaned_static_template_2024-05-15.pkl
# Procesando día 2024-05-16…
#   → guardado: processed_by_date/cleaned_static_template_2024-05-16.pkl
# Procesando día 2024-05-17…
#   → guardado: processed_by_date/cleaned_static_template_2024-05-17.pkl
# Procesando día 2024-05-18…
#   → guardado: processed_by_date/cleaned_static_template_2024-05-18.pkl
# Procesando día 2024-05-19…
#   → No servicios válidos para 2024-05-19, saltando.
# Procesando día 2024-05-20…
#   → guardado: processed_by_date/cleaned_static_template_2024-05-20.pkl
# Procesando día 2024-05-21…
#   → guardado: processed_by_date/cleaned_static_template_2024-05-21.pkl
# Procesando día 2024-05-22…
#   → guardado: processed_by_date/cleaned_static_template_2024-05-22.pkl
# Procesando día 2024-05-23…
#   → guardado: processed_by_date/cleaned_static_template_2024-05-23.pkl
# Procesando día 2024-05-24…
#   → guardado: processed_by_date/cleaned_static_template_2024-05-24.pkl
# Procesando día 2024-05-25…
#   → guardado: processed_by_date/cleaned_static_template_2024-05-25.pkl
# Procesando día 2024-05-26…
#   → No servicios válidos para 2024-05-26, saltando.
# Procesando día 2024-05-27…
#   → guardado: processed_by_date/cleaned_static_template_2024-05-27.pkl
# Procesando día 2024-05-28…
#   → guardado: processed_by_date/cleaned_static_template_2024-05-28.pkl
# Procesando día 2024-05-29…
#   → guardado: processed_by_date/cleaned_static_template_2024-05-29.pkl
# Procesando día 2024-05-30…
#   → guardado: processed_by_date/cleaned_static_template_2024-05-30.pkl
# Procesando día 2024-05-31…
#   → guardado: processed_by_date/cleaned_static_template_2024-05-31.pkl
# Procesando día 2024-06-01…
#   → guardado: processed_by_date/cleaned_static_template_2024-06-01.pkl
# Procesando día 2024-06-02…
#   → No servicios válidos para 2024-06-02, saltando.
# Procesando día 2024-06-03…
#   → No servicios válidos para 2024-06-03, saltando.
# Procesando día 2024-06-04…
#   → guardado: processed_by_date/cleaned_static_template_2024-06-04.pkl
# Procesando día 2024-06-05…
#   → guardado: processed_by_date/cleaned_static_template_2024-06-05.pkl
# Procesando día 2024-06-06…
#   → guardado: processed_by_date/cleaned_static_template_2024-06-06.pkl
# Procesando día 2024-06-07…
#   → guardado: processed_by_date/cleaned_static_template_2024-06-07.pkl
# Procesando día 2024-06-08…
#   → guardado: processed_by_date/cleaned_static_template_2024-06-08.pkl
# Procesando día 2024-06-09…
#   → No servicios válidos para 2024-06-09, saltando.
# Procesando día 2024-06-10…
#   → No servicios válidos para 2024-06-10, saltando.
# Procesando día 2024-06-11…
#   → guardado: processed_by_date/cleaned_static_template_2024-06-11.pkl
# Procesando día 2024-06-12…
#   → guardado: processed_by_date/cleaned_static_template_2024-06-12.pkl
# Procesando día 2024-06-13…
#   → guardado: processed_by_date/cleaned_static_template_2024-06-13.pkl
# Procesando día 2024-06-14…
#   → guardado: processed_by_date/cleaned_static_template_2024-06-14.pkl
# Procesando día 2024-06-15…
#   → guardado: processed_by_date/cleaned_static_template_2024-06-15.pkl
# Procesando día 2024-06-16…
#   → No servicios válidos para 2024-06-16, saltando.
# Procesando día 2024-06-17…
#   → guardado: processed_by_date/cleaned_static_template_2024-06-17.pkl
# ...
#   → No servicios válidos para 2024-12-22, saltando.
# Procesando día 2024-12-23…
#   → guardado: processed_by_date/cleaned_static_template_2024-12-23.pkl
# Procesando día 2024-12-24…
#   → guardado: processed_by_date/cleaned_static_template_2024-12-24.pkl
# Procesando día 2024-12-25…
#   → No servicios válidos para 2024-12-25, saltando.
# Procesando día 2024-12-26…
#   → guardado: processed_by_date/cleaned_static_template_2024-12-26.pkl
# Procesando día 2024-12-27…
#   → guardado: processed_by_date/cleaned_static_template_2024-12-27.pkl
# Procesando día 2024-12-28…
#   → guardado: processed_by_date/cleaned_static_template_2024-12-28.pkl
# Procesando día 2024-12-29…
#   → No servicios válidos para 2024-12-29, saltando.
# Procesando día 2024-12-30…
#   → guardado: processed_by_date/cleaned_static_template_2024-12-30.pkl
# Procesando día 2024-12-31…
#   → guardado: processed_by_date/cleaned_static_template_2024-12-31.pkl
# Procesando día 2025-01-01…
#   → No servicios válidos para 2025-01-01, saltando.
# Procesando día 2025-01-02…
#   → guardado: processed_by_date/cleaned_static_template_2025-01-02.pkl
# Procesando día 2025-01-03…
#   → guardado: processed_by_date/cleaned_static_template_2025-01-03.pkl
# Procesando día 2025-01-04…
#   → guardado: processed_by_date/cleaned_static_template_2025-01-04.pkl
# Procesando día 2025-01-05…
#   → No servicios válidos para 2025-01-05, saltando.
# Procesando día 2025-01-06…
#   → guardado: processed_by_date/cleaned_static_template_2025-01-06.pkl
# Procesando día 2025-01-07…
#   → guardado: processed_by_date/cleaned_static_template_2025-01-07.pkl
# Procesando día 2025-01-08…
#   → guardado: processed_by_date/cleaned_static_template_2025-01-08.pkl
# Procesando día 2025-01-09…
#   → guardado: processed_by_date/cleaned_static_template_2025-01-09.pkl
# Procesando día 2025-01-10…
#   → guardado: processed_by_date/cleaned_static_template_2025-01-10.pkl
# Procesando día 2025-01-11…
#   → guardado: processed_by_date/cleaned_static_template_2025-01-11.pkl
# Procesando día 2025-01-12…
#   → No servicios válidos para 2025-01-12, saltando.
# Procesando día 2025-01-13…
#   → guardado: processed_by_date/cleaned_static_template_2025-01-13.pkl
# Procesando día 2025-01-14…
#   → guardado: processed_by_date/cleaned_static_template_2025-01-14.pkl
# Procesando día 2025-01-15…
#   → guardado: processed_by_date/cleaned_static_template_2025-01-15.pkl
# Procesando día 2025-01-16…
#   → guardado: processed_by_date/cleaned_static_template_2025-01-16.pkl
# Procesando día 2025-01-17…
#   → guardado: processed_by_date/cleaned_static_template_2025-01-17.pkl
# Procesando día 2025-01-18…
#   → guardado: processed_by_date/cleaned_static_template_2025-01-18.pkl
# Procesando día 2025-01-19…
#   → No servicios válidos para 2025-01-19, saltando.
# Procesando día 2025-01-20…
#   → guardado: processed_by_date/cleaned_static_template_2025-01-20.pkl
# Procesando día 2025-01-21…
#   → guardado: processed_by_date/cleaned_static_template_2025-01-21.pkl
# Procesando día 2025-01-22…
#   → guardado: processed_by_date/cleaned_static_template_2025-01-22.pkl
# Procesando día 2025-01-23…
#   → guardado: processed_by_date/cleaned_static_template_2025-01-23.pkl
# Procesando día 2025-01-24…
#   → guardado: processed_by_date/cleaned_static_template_2025-01-24.pkl
# Procesando día 2025-01-25…
#   → guardado: processed_by_date/cleaned_static_template_2025-01-25.pkl
# Procesando día 2025-01-26…
#   → No servicios válidos para 2025-01-26, saltando.
# Procesando día 2025-01-27…
#   → guardado: processed_by_date/cleaned_static_template_2025-01-27.pkl
# Procesando día 2025-01-28…
#   → guardado: processed_by_date/cleaned_static_template_2025-01-28.pkl
# Procesando día 2025-01-29…
#   → guardado: processed_by_date/cleaned_static_template_2025-01-29.pkl
# Procesando día 2025-01-30…
#   → guardado: processed_by_date/cleaned_static_template_2025-01-30.pkl
# Procesando día 2025-01-31…
#   → guardado: processed_by_date/cleaned_static_template_2025-01-31.pkl
# Procesando día 2025-02-01…
#   → guardado: processed_by_date/cleaned_static_template_2025-02-01.pkl
# Procesando día 2025-02-02…
#   → No servicios válidos para 2025-02-02, saltando.
# Procesando día 2025-02-03…
#   → guardado: processed_by_date/cleaned_static_template_2025-02-03.pkl
# Procesando día 2025-02-04…
#   → guardado: processed_by_date/cleaned_static_template_2025-02-04.pkl
# Procesando día 2025-02-05…
#   → guardado: processed_by_date/cleaned_static_template_2025-02-05.pkl
# Procesando día 2025-02-06…
#   → guardado: processed_by_date/cleaned_static_template_2025-02-06.pkl
# Procesando día 2025-02-07…
#   → guardado: processed_by_date/cleaned_static_template_2025-02-07.pkl
# Procesando día 2025-02-08…
#   → guardado: processed_by_date/cleaned_static_template_2025-02-08.pkl
# Procesando día 2025-02-09…
#   → No servicios válidos para 2025-02-09, saltando.
# Procesando día 2025-02-10…
#   → guardado: processed_by_date/cleaned_static_template_2025-02-10.pkl
# Procesando día 2025-02-11…
#   → guardado: processed_by_date/cleaned_static_template_2025-02-11.pkl
# Procesando día 2025-02-12…
#   → guardado: processed_by_date/cleaned_static_template_2025-02-12.pkl
# Procesando día 2025-02-13…
#   → guardado: processed_by_date/cleaned_static_template_2025-02-13.pkl
# Procesando día 2025-02-14…
#   → guardado: processed_by_date/cleaned_static_template_2025-02-14.pkl
# Procesando día 2025-02-15…
#   → guardado: processed_by_date/cleaned_static_template_2025-02-15.pkl
# Procesando día 2025-02-16…
#   → No servicios válidos para 2025-02-16, saltando.
# Procesando día 2025-02-17…
#   → guardado: processed_by_date/cleaned_static_template_2025-02-17.pkl
# Procesando día 2025-02-18…
#   → guardado: processed_by_date/cleaned_static_template_2025-02-18.pkl
# Procesando día 2025-02-19…
#   → guardado: processed_by_date/cleaned_static_template_2025-02-19.pkl
# Procesando día 2025-02-20…
#   → guardado: processed_by_date/cleaned_static_template_2025-02-20.pkl
# Procesando día 2025-02-21…
#   → guardado: processed_by_date/cleaned_static_template_2025-02-21.pkl
# Procesando día 2025-02-22…
#   → guardado: processed_by_date/cleaned_static_template_2025-02-22.pkl
# Procesando día 2025-02-23…
#   → No servicios válidos para 2025-02-23, saltando.
# Procesando día 2025-02-24…
#   → guardado: processed_by_date/cleaned_static_template_2025-02
28…
#   → guardado: processed_by_date/cleaned_static_template_2025-04-28.pkl
# Procesando día 2025-04-29…
#   → guardado: processed_by_date/cleaned_static_template_2025-04-29.pkl
# Procesando día 2025-04-30…
#   → guardado: processed_by_date/cleaned_static_template_2025-04-30.pkl
# Procesando día 2025-05-01…
#   → No servicios válidos para 2025-05-01, saltando.
# Procesando día 2025-05-02…
#   → guardado: processed_by_date/cleaned_static_template_2025-05-02.pkl
# Procesando día 2025-05-03…
#   → guardado: processed_by_date/cleaned_static_template_2025-05-03.pkl
# Procesando día 2025-05-04…
#   → No servicios válidos para 2025-05-04, saltando.
# Procesando día 2025-05-05…
#   → guardado: processed_by_date/cleaned_static_template_2025-05-05.pkl
# Procesando día 2025-05-06…
#   → guardado: processed_by_date/cleaned_static_template_2025-05-06.pkl
# Procesando día 2025-05-07…
#   → guardado: processed_by_date/cleaned_static_template_2025-05-07.pkl
# Procesando día 2025-05-08…
#   → guardado: processed_by_date/cleaned_static_template_2025-05-08.pkl
# Procesando día 2025-05-09…
#   → guardado: processed_by_date/cleaned_static_template_2025-05-09.pkl
# Procesando día 2025-05-10…
#   → guardado: processed_by_date/cleaned_static_template_2025-05-10.pkl
# Procesando día 2025-05-11…
#   → No servicios válidos para 2025-05-11, saltando.
# Procesando día 2025-05-12…
#   → guardado: processed_by_date/cleaned_static_template_2025-05-12.pkl
# Procesando día 2025-05-13…
#   → guardado: processed_by_date/cleaned_static_template_2025-05-13.pkl
# Procesando día 2025-05-14…
#   → guardado: processed_by_date/cleaned_static_template_2025-05-14.pkl
# Procesando día 2025-05-15…
#   → guardado: processed_by_date/cleaned_static_template_2025-05-15.pkl
# Procesando día 2025-05-16…
#   → guardado: processed_by_date/cleaned_static_template_2025-05-16.pkl
# Procesando día 2025-05-17…
#   → guardado: processed_by_date/cleaned_static_template_2025-05-17.pkl
# Procesando día 2025-05-18…
#   → No servicios válidos para 2025-05-18, saltando.
# Procesando día 2025-05-19…
#   → guardado: processed_by_date/cleaned_static_template_2025-05-19.pkl
# Procesando día 2025-05-20…
#   → guardado: processed_by_date/cleaned_static_template_2025-05-20.pkl
# Procesando día 2025-05-21…
#   → guardado: processed_by_date/cleaned_static_template_2025-05-21.pkl
# Procesando día 2025-05-22…
#   → guardado: processed_by_date/cleaned_static_template_2025-05-22.pkl
# Procesando día 2025-05-23…
#   → guardado: processed_by_date/cleaned_static_template_2025-05-23.pkl
# Procesando día 2025-05-24…
#   → guardado: processed_by_date/cleaned_static_template_2025-05-24.pkl
# Procesando día 2025-05-25…
#   → No servicios válidos para 2025-05-25, saltando.
# Procesando día 2025-05-26…
#   → guardado: processed_by_date/cleaned_static_template_2025-05-26.pkl
# Procesando día 2025-05-27…
#   → guardado: processed_by_date/cleaned_static_template_2025-05-27.pkl
# Procesando día 2025-05-28…
#   → guardado: processed_by_date/cleaned_static_template_2025-05-28.pkl
# Procesando día 2025-05-29…
#   → guardado: processed_by_date/cleaned_static_template_2025-05-29.pkl
# Procesando día 2025-05-30…
#   → guardado: processed_by_date/cleaned_static_template_2025-05-30.pkl
# Procesando día 2025-05-31…
#   → guardado: processed_by_date/cleaned_static_template_2025-05-31.pkl
# Procesando día 2025-06-03…
#   → guardado: processed_by_date/cleaned_static_template_2025-06-03.pkl
# Procesando día 2025-06-04…
#   → guardado: processed_by_date/cleaned_static_template_2025-06-04.pkl
# Procesando día 2025-06-06…
#   → No servicios válidos para 2025-06-06, saltando.
# Procesando día 2025-06-07…
#   → No servicios válidos para 2025-06-07, saltando.
# Procesando día 2025-06-08…
#   → No servicios válidos para 2025-06-08, saltando.
# Procesando día 2025-06-09…
#   → guardado: processed_by_date/cleaned_static_template_2025-06-09.pkl
# Procesando día 2025-06-12…
#   → guardado: processed_by_date/cleaned_static_template_2025-06-12.pkl
# Procesando día 2025-06-16…
#   → guardado: processed_by_date/cleaned_static_template_2025-06-16.pkl
# Procesando día 2025-07-01…
#   → guardado: processed_by_date/cleaned_static_template_2025-07-01.pkl
# ✅ BLOQUE 1 completado para todos los días.

# %%
# Código para listar el top de días según número de labors procesadas

import glob
import os
import pandas as pd

# 1) Encuentra todos los archivos de plantillas por día
pattern = os.path.join("processed_by_date", "cleaned_static_template_*.pkl")
files = glob.glob(pattern)

# 2) Para cada archivo, extraer la fecha y contar las filas
day_counts = []
for path in files:
    # El nombre es ".../cleaned_static_template_YYYY-MM-DD.pkl"
    filename = os.path.basename(path)
    # Extraemos la parte "YYYY-MM-DD" del nombre
    day_str = filename.replace("cleaned_static_template_", "").replace(".pkl", "")
    # Cargamos el DataFrame y contamos las filas
    df = pd.read_pickle(path)
    day_counts.append({
        "day": day_str,
        "num_labors": len(df)
    })

# 3) Armamos el DataFrame de conteos y ordenamos de mayor a menor
df_counts = (
    pd.DataFrame(day_counts)
      .sort_values("num_labors", ascending=False)
      .reset_index(drop=True)
)

# 4) Mostramos el top 10 (o todos si lo prefieres)
top_n = 10
print(f"Top {top_n} días por número de labors procesadas:")
print(df_counts.head(top_n).to_string(index=False))
# Out:
# Top 10 días por número de labors procesadas:
#        day  num_labors
# 2023-03-30         190
# 2023-01-17         189
# 2023-01-30         188
# 2023-01-31         164
# 2023-12-06         164
# 2023-01-16         161
# 2023-03-21         161
# 2023-03-31         161
# 2023-08-30         160
# 2023-05-30         158

# %%
df_counts
# Out:
#             day  num_labors
# 0    2023-03-30         190
# 1    2023-01-17         189
# 2    2023-01-30         188
# 3    2023-01-31         164
# 4    2023-12-06         164
# ..          ...         ...
# 726  2023-11-05           1
# 727  2025-06-09           1
# 728  2025-06-12           1
# 729  2025-06-16           1
# 730  2025-07-01           1
#
# [731 rows x 2 columns]

# %%
import os
import pickle
import pandas as pd
import math
import requests
import random
from datetime import datetime, timedelta
from filtros_df import filter_labors_by_city

SEED = 10
DISTANCE_METHOD = 'Manhattan'
alfred_speed = 30
vehicle_transport_speed = 40
tiempo_previo = 30
tiempo_gracia = 15
tiempo_alistar = 15
tiempo_other = 30
tiempo_finalizacion = 15

random.seed(SEED)

os.makedirs("processed_by_date", exist_ok=True)

directorio_df = pd.read_csv("Datos/Procesados/directorio_df.csv")
df_raw = pd.read_csv("Datos/Procesados/df_dist.csv")
# asegurar columnas de fecha como datetime
date_cols = ['schedule_date', 'labor_start_date', 'labor_end_date']
for col in date_cols:
    df_raw[col] = pd.to_datetime(df_raw[col], errors='coerce')

with open('distances.pkl', 'rb') as f:
    DIST_DICT = pickle.load(f)


def parse_point(s):
    if pd.isna(s) or not isinstance(s, str) or not s.strip().startswith("POINT"):
        return None, None
    lon, lat = map(float, s.lstrip('POINT').strip(' ()').split())
    return lat, lon

OSRM_URL = "http://router.project-osrm.org/route/v1/driving/"
def distance(p1, p2, method='haversine', timeout=5):
    if method == 'precalced':
        return DIST_DICT.get((p1, p2), float('nan'))
    lat1, lon1 = parse_point(p1)
    lat2, lon2 = parse_point(p2)
    if None in (lat1, lon1, lat2, lon2):
        return float('nan')
    if method == 'haversine':
        φ1, φ2 = map(math.radians, (lat1, lat2))
        dφ = math.radians(lat2 - lat1)
        dλ = math.radians(lon2 - lon1)
        a = math.sin(dφ/2)**2 + math.cos(φ1)*math.cos(φ2)*math.sin(dλ/2)**2
        return 2 * 6371 * math.atan2(math.sqrt(a), math.sqrt(1 - a))
    if method == 'osrm':
        coords = f"{lon1},{lat1};{lon2},{lat2}"
        try:
            r = requests.get(OSRM_URL + coords + "?overview=false", timeout=timeout)
            r.raise_for_status()
            return r.json()['routes'][0]['distance'] / 1000
        except:
            return distance(p1, p2, method='haversine')
    mean_lat = math.radians((lat1 + lat2) / 2)
    dlat = abs(lat1 - lat2) * 111.32
    dlon = abs(lon1 - lon2) * 111.32 * math.cos(mean_lat)
    return dlat + dlon


def process_group(grp):
    if len(grp) == 1:
        return grp if grp.iloc[0]['labor_category'] == 'VEHICLE_TRANSPORTATION' else grp.iloc[0:0]
    A_idx = grp.index[grp['labor_category'] == 'VEHICLE_TRANSPORTATION'].tolist()
    if not A_idx:
        return grp.iloc[0:0]
    B_idx = [i for i in grp.index if grp.at[i,'labor_category'] != 'VEHICLE_TRANSPORTATION'
             and pd.notna(grp.at[i,'shop']) and pd.notna(grp.at[i,'address_point'])]
    if not B_idx:
        return grp.iloc[0:0]
    inits = [i for i in A_idx if grp.at[i,'labor_name'] == 'Alfred Initial Transport']
    firstA = inits[0] if inits else A_idx[0]
    A_rem = [i for i in A_idx if i != firstA]
    start_pt = grp['start_address_point'].iloc[0]
    dist_map = {i: distance(start_pt, grp.at[i,'address_point']) for i in B_idx}
    B_sorted = sorted(B_idx, key=lambda i: dist_map[i])[:len(A_idx)-1]
    A_rem_sorted = sorted(A_rem, key=lambda i: grp.at[i,'labor_start_date'])
    needed_A = [firstA] + A_rem_sorted[:len(B_sorted)]
    final = []
    for j, b in enumerate(B_sorted):
        final += [needed_A[j], b]
    final.append(needed_A[-1])
    return grp.loc[final]


df_temp = (
    df_raw.dropna(subset=['labor_start_date', 'labor_end_date'])
          .assign(duration_td=lambda d: d['labor_end_date'] - d['labor_start_date'])
)
df_temp = df_temp[df_temp['duration_td'] <= pd.Timedelta(days=1)]
df_temp['duration_min'] = df_temp['duration_td'].dt.total_seconds() / 60
avg_times_map = df_temp.groupby('labor_name')['duration_min'].mean().to_dict()

df_bogota = filter_labors_by_city(df_raw, 149)
unique_days = sorted(df_bogota['schedule_date'].dt.date.dropna().unique())

for day in unique_days:
    day_str = day.isoformat()
    print(f"Procesando día {day_str}…")
    df_dia = df_bogota[df_bogota['schedule_date'].dt.date == day].copy()
    if df_dia.empty:
        print(f"  → Sin datos para {day_str}, saltando.")
        continue
    base_day = day
    def remap_to_base(dt):
        if pd.isna(dt): return dt
        delta = (base_day - dt.date()).days
        return dt + timedelta(days=delta)
    for c in date_cols:
        df_dia[c] = df_dia[c].apply(remap_to_base)
    map_src = df_dia[['service_id', 'labor_id', 'labor_category',
                      'start_address_point', 'end_address_point', 'address_point',
                      'labor_start_date']]
    map_src = map_src.sort_values(['service_id', 'labor_start_date']).reset_index(drop=True)
    rows = []
    for svc, grp in map_src.groupby('service_id', sort=False):
        n = len(grp)
        idxs = grp.index.tolist()
        for i, idx in enumerate(idxs):
            r = grp.loc[idx]
            if n == 1:
                sp, ep = r['start_address_point'], r['end_address_point']
            else:
                if r['labor_category'] == 'VEHICLE_TRANSPORTATION':
                    sp = r['start_address_point']
                    ep = grp.iloc[i+1]['end_address_point'] if i < n-1 else r['end_address_point']
                else:
                    sp = ep = r['address_point']
            rows.append({'service_id': svc, 'labor_id': r['labor_id'],
                         'map_start_point': sp, 'map_end_point': ep})
    services_map_df = pd.DataFrame(rows)
    services_map_df['labor_id'] = services_map_df['labor_id'].astype(df_dia['labor_id'].dtype)
    cleaned = []
    for svc, grp in df_dia.groupby('service_id', sort=False):
        pg = process_group(grp)
        if not pg.empty:
            cleaned.append(pg)
    if not cleaned:
        print(f"  → No servicios válidos para {day_str}, saltando.")
        continue
    df_cleaned_template = (
        pd.concat(cleaned, ignore_index=True)
          .merge(services_map_df, on=['service_id','labor_id'], how='left')
    )
    out_path_pkl = f"processed_by_date/cleaned_static_template_{day_str}.pkl"
    out_path_csv = f"processed_by_date/cleaned_static_template_{day_str}.csv"
    df_cleaned_template.to_pickle(out_path_pkl)
    df_cleaned_template.to_csv(out_path_csv, index=False)
    print(f"  → guardado: {out_path_pkl} y {out_path_csv}")

print("✅ BLOQUE 1 completado para todos los días.")
# Out:
# Procesando día 2023-01-02…
#   → guardado: processed_by_date/cleaned_static_template_2023-01-02.pkl y processed_by_date/cleaned_static_template_2023-01-02.csv
# Procesando día 2023-01-03…
#   → guardado: processed_by_date/cleaned_static_template_2023-01-03.pkl y processed_by_date/cleaned_static_template_2023-01-03.csv
# Procesando día 2023-01-04…
#   → guardado: processed_by_date/cleaned_static_template_2023-01-04.pkl y processed_by_date/cleaned_static_template_2023-01-04.csv
# Procesando día 2023-01-05…
#   → guardado: processed_by_date/cleaned_static_template_2023-01-05.pkl y processed_by_date/cleaned_static_template_2023-01-05.csv
# Procesando día 2023-01-06…
#   → guardado: processed_by_date/cleaned_static_template_2023-01-06.pkl y processed_by_date/cleaned_static_template_2023-01-06.csv
# Procesando día 2023-01-07…
#   → guardado: processed_by_date/cleaned_static_template_2023-01-07.pkl y processed_by_date/cleaned_static_template_2023-01-07.csv
# Procesando día 2023-01-10…
#   → guardado: processed_by_date/cleaned_static_template_2023-01-10.pkl y processed_by_date/cleaned_static_template_2023-01-10.csv
# Procesando día 2023-01-11…
#   → guardado: processed_by_date/cleaned_static_template_2023-01-11.pkl y processed_by_date/cleaned_static_template_2023-01-11.csv
# Procesando día 2023-01-12…
#   → guardado: processed_by_date/cleaned_static_template_2023-01-12.pkl y processed_by_date/cleaned_static_template_2023-01-12.csv
# Procesando día 2023-01-13…
#   → guardado: processed_by_date/cleaned_static_template_2023-01-13.pkl y processed_by_date/cleaned_static_template_2023-01-13.csv
# Procesando día 2023-01-14…
#   → guardado: processed_by_date/cleaned_static_template_2023-01-14.pkl y processed_by_date/cleaned_static_template_2023-01-14.csv
# Procesando día 2023-01-16…
#   → guardado: processed_by_date/cleaned_static_template_2023-01-16.pkl y processed_by_date/cleaned_static_template_2023-01-16.csv
# Procesando día 2023-01-17…
#   → guardado: processed_by_date/cleaned_static_template_2023-01-17.pkl y processed_by_date/cleaned_static_template_2023-01-17.csv
# Procesando día 2023-01-18…
#   → guardado: processed_by_date/cleaned_static_template_2023-01-18.pkl y processed_by_date/cleaned_static_template_2023-01-18.csv
# Procesando día 2023-01-19…
#   → guardado: processed_by_date/cleaned_static_template_2023-01-19.pkl y processed_by_date/cleaned_static_template_2023-01-19.csv
# Procesando día 2023-01-20…
#   → guardado: processed_by_date/cleaned_static_template_2023-01-20.pkl y processed_by_date/cleaned_static_template_2023-01-20.csv
# Procesando día 2023-01-21…
#   → guardado: processed_by_date/cleaned_static_template_2023-01-21.pkl y processed_by_date/cleaned_static_template_2023-01-21.csv
# Procesando día 2023-01-23…
#   → guardado: processed_by_date/cleaned_static_template_2023-01-23.pkl y processed_by_date/cleaned_static_template_2023-01-23.csv
# Procesando día 2023-01-24…
#   → guardado: processed_by_date/cleaned_static_template_2023-01-24.pkl y processed_by_date/cleaned_static_template_2023-01-24.csv
# Procesando día 2023-01-25…
#   → guardado: processed_by_date/cleaned_static_template_2023-01-25.pkl y processed_by_date/cleaned_static_template_2023-01-25.csv
# Procesando día 2023-01-26…
#   → guardado: processed_by_date/cleaned_static_template_2023-01-26.pkl y processed_by_date/cleaned_static_template_2023-01-26.csv
# Procesando día 2023-01-27…
#   → guardado: processed_by_date/cleaned_static_template_2023-01-27.pkl y processed_by_date/cleaned_static_template_2023-01-27.csv
# Procesando día 2023-01-28…
#   → guardado: processed_by_date/cleaned_static_template_2023-01-28.pkl y processed_by_date/cleaned_static_template_2023-01-28.csv
# Procesando día 2023-01-30…
#   → guardado: processed_by_date/cleaned_static_template_2023-01-30.pkl y processed_by_date/cleaned_static_template_2023-01-30.csv
# Procesando día 2023-01-31…
#   → guardado: processed_by_date/cleaned_static_template_2023-01-31.pkl y processed_by_date/cleaned_static_template_2023-01-31.csv
# Procesando día 2023-02-01…
#   → guardado: processed_by_date/cleaned_static_template_2023-02-01.pkl y processed_by_date/cleaned_static_template_2023-02-01.csv
# Procesando día 2023-02-02…
#   → guardado: processed_by_date/cleaned_static_template_2023-02-02.pkl y processed_by_date/cleaned_static_template_2023-02-02.csv
# Procesando día 2023-02-03…
#   → guardado: processed_by_date/cleaned_static_template_2023-02-03.pkl y processed_by_date/cleaned_static_template_2023-02-03.csv
# Procesando día 2023-02-04…
#   → guardado: processed_by_date/cleaned_static_template_2023-02-04.pkl y processed_by_date/cleaned_static_template_2023-02-04.csv
# Procesando día 2023-02-06…
#   → guardado: processed_by_date/cleaned_static_template_2023-02-06.pkl y processed_by_date/cleaned_static_template_2023-02-06.csv
# Procesando día 2023-02-07…
#   → guardado: processed_by_date/cleaned_static_template_2023-02-07.pkl y processed_by_date/cleaned_static_template_2023-02-07.csv
# Procesando día 2023-02-08…
#   → guardado: processed_by_date/cleaned_static_template_2023-02-08.pkl y processed_by_date/cleaned_static_template_2023-02-08.csv
# Procesando día 2023-02-09…
#   → guardado: processed_by_date/cleaned_static_template_2023-02-09.pkl y processed_by_date/cleaned_static_template_2023-02-09.csv
# Procesando día 2023-02-10…
#   → guardado: processed_by_date/cleaned_static_template_2023-02-10.pkl y processed_by_date/cleaned_static_template_2023-02-10.csv
# Procesando día 2023-02-11…
#   → guardado: processed_by_date/cleaned_static_template_2023-02-11.pkl y processed_by_date/cleaned_static_template_2023-02-11.csv
# Procesando día 2023-02-13…
#   → guardado: processed_by_date/cleaned_static_template_2023-02-13.pkl y processed_by_date/cleaned_static_template_2023-02-13.csv
# Procesando día 2023-02-14…
#   → guardado: processed_by_date/cleaned_static_template_2023-02-14.pkl y processed_by_date/cleaned_static_template_2023-02-14.csv
# Procesando día 2023-02-15…
#   → guardado: processed_by_date/cleaned_static_template_2023-02-15.pkl y processed_by_date/cleaned_static_template_2023-02-15.csv
# Procesando día 2023-02-16…
#   → guardado: processed_by_date/cleaned_static_template_2023-02-16.pkl y processed_by_date/cleaned_static_template_2023-02-16.csv
# Procesando día 2023-02-17…
#   → guardado: processed_by_date/cleaned_static_template_2023-02-17.pkl y processed_by_date/cleaned_static_template_2023-02-17.csv
# Procesando día 2023-02-18…
#   → guardado: processed_by_date/cleaned_static_template_2023-02-18.pkl y processed_by_date/cleaned_static_template_2023-02-18.csv
# Procesando día 2023-02-20…
#   → guardado: processed_by_date/cleaned_static_template_2023-02-20.pkl y processed_by_date/cleaned_static_template_2023-02-20.csv
# Procesando día 2023-02-21…
#   → guardado: processed_by_date/cleaned_static_template_2023-02-21.pkl y processed_by_date/cleaned_static_template_2023-02-21.csv
# Procesando día 2023-02-22…
#   → guardado: processed_by_date/cleaned_static_template_2023-02-22.pkl y processed_by_date/cleaned_static_template_2023-02-22.csv
# Procesando día 2023-02-23…
#   → guardado: processed_by_date/cleaned_static_template_2023-02-23.pkl y processed_by_date/cleaned_static_template_2023-02-23.csv
# Procesando día 2023-02-24…
#   → guardado: processed_by_date/cleaned_static_template_2023-02-24.pkl y processed_by_date/cleaned_static_template_2023-02-24.csv
# Procesando día 2023-02-25…
#   → guardado: processed_by_date/cleaned_static_template_2023-02-25.pkl y processed_by_date/cleaned_static_template_2023-02-25.csv
# Procesando día 2023-02-27…
#   → guardado: processed_by_date/cleaned_static_template_2023-02-27.pkl y processed_by_date/cleaned_static_template_2023-02-27.csv
# Procesando día 2023-02-28…
#   → guardado: processed_by_date/cleaned_static_template_2023-02-28.pkl y processed_by_date/cleaned_static_template_2023-02-28.csv
# Procesando día 2023-03-01…
#   → guardado: processed_by_date/cleaned_static_template_2023-03-01.pkl y processed_by_date/cleaned_static_template_2023-03-01.csv
# Procesando día 2023-03-02…
#   → guardado: processed_by_date/cleaned_static_template_2023-03-02.pkl y processed_by_date/cleaned_static_template_2023-03-02.csv
# Procesando día 2023-03-03…
#   → guardado: processed_by_date/cleaned_static_template_2023-03-03.pkl y processed_by_date/cleaned_static_template_2023-03-03.csv
# Procesando día 2023-03-04…
#   → guardado: processed_by_date/cleaned_static_template_2023-03-04.pkl y processed_by_date/cleaned_static_template_2023-03-04.csv
# Procesando día 2023-03-06…
#   → guardado: processed_by_date/cleaned_static_template_2023-03-06.pkl y processed_by_date/cleaned_static_template_2023-03-06.csv
# Procesando día 2023-03-07…
#   → guardado: processed_by_date/cleaned_static_template_2023-03-07.pkl y processed_by_date/cleaned_static_template_2023-03-07.csv
# Procesando día 2023-03-08…
#   → guardado: processed_by_date/cleaned_static_template_2023-03-08.pkl y processed_by_date/cleaned_static_template_2023-03-08.csv
# Procesando día 2023-03-09…
#   → guardado: processed_by_date/cleaned_static_template_2023-03-09.pkl y processed_by_date/cleaned_static_template_2023-03-09.csv
# Procesando día 2023-03-10…
#   → guardado: processed_by_date/cleaned_static_template_2023-03-10.pkl y processed_by_date/cleaned_static_template_2023-03-10.csv
# Procesando día 2023-03-11…
#   → guardado: processed_by_date/cleaned_static_template_2023-03-11.pkl y processed_by_date/cleaned_static_template_2023-03-11.csv
# Procesando día 2023-03-13…
#   → guardado: processed_by_date/cleaned_static_template_2023-03-13.pkl y processed_by_date/cleaned_static_template_2023-03-13.csv
# Procesando día 2023-03-14…
#   → guardado: processed_by_date/cleaned_static_template_2023-03-14.pkl y processed_by_date/cleaned_static_template_2023-03-14.csv
# Procesando día 2023-03-15…
#   → guardado: processed_by_date/cleaned_static_template_2023-03-15.pkl y processed_by_date/cleaned_static_template_2023-03-15.csv
# Procesando día 2023-03-16…
#   → guardado: processed_by_date/cleaned_static_template_2023-03-16.pkl y processed_by_date/cleaned_static_template_2023-03-16.csv
# Procesando día 2023-03-17…
#   → guardado: processed_by_date/cleaned_static_template_2023-03-17.pkl y processed_by_date/cleaned_static_template_2023-03-17.csv
# Procesando día 2023-03-18…
#   → guardado: processed_by_date/cleaned_static_template_2023-03-18.pkl y processed_by_date/cleaned_static_template_2023-03-18.csv
# Procesando día 2023-03-21…
#   → guardado: processed_by_date/cleaned_static_template_2023-03-21.pkl y processed_by_date/cleaned_static_template_2023-03-21.csv
# Procesando día 2023-03-22…
#   → guardado: processed_by_date/cleaned_static_template_2023-03-22.pkl y processed_by_date/cleaned_static_template_2023-03-22.csv
# Procesando día 2023-03-23…
#   → guardado: processed_by_date/cleaned_static_template_2023-03-23.pkl y processed_by_date/cleaned_static_template_2023-03-23.csv
# Procesando día 2023-03-24…
#   → guardado: processed_by_date/cleaned_static_template_2023-03-24.pkl y processed_by_date/cleaned_static_template_2023-03-24.csv
# Procesando día 2023-03-25…
#   → guardado: processed_by_date/cleaned_static_template_2023-03-25.pkl y processed_by_date/cleaned_static_template_2023-03-25.csv
# Procesando día 2023-03-27…
#   → guardado: processed_by_date/cleaned_static_template_2023-03-27.pkl y processed_by_date/cleaned_static_template_2023-03-27.csv
# Procesando día 2023-03-28…
#   → guardado: processed_by_date/cleaned_static_template_2023-03-28.pkl y processed_by_date/cleaned_static_template_2023-03-28.csv
# Procesando día 2023-03-29…
#   → guardado: processed_by_date/cleaned_static_template_2023-03-29.pkl y processed_by_date/cleaned_static_template_2023-03-29.csv
# Procesando día 2023-03-30…
#   → guardado: processed_by_date/cleaned_static_template_2023-03-30.pkl y processed_by_date/cleaned_static_template_2023-03-30.csv
# Procesando día 2023-03-31…
#   → guardado: processed_by_date/cleaned_static_template_2023-03-31.pkl y processed_by_date/cleaned_static_template_2023-03-31.csv
# Procesando día 2023-04-01…
#   → guardado: processed_by_date/cleaned_static_template_2023-04-01.pkl y processed_by_date/cleaned_static_template_2023-04-01.csv
# Procesando día 2023-04-03…
#   → guardado: processed_by_date/cleaned_static_template_2023-04-03.pkl y processed_by_date/cleaned_static_template_2023-04-03.csv
# Procesando día 2023-04-04…
#   → guardado: processed_by_date/cleaned_static_template_2023-04-04.pkl y processed_by_date/cleaned_static_template_2023-04-04.csv
# Procesando día 2023-04-05…
#   → guardado: processed_by_date/cleaned_static_template_2023-04-05.pkl y processed_by_date/cleaned_static_template_2023-04-05.csv
# Procesando día 2023-04-08…
#   → guardado: processed_by_date/cleaned_static_template_2023-04-08.pkl y processed_by_date/cleaned_static_template_2023-04-08.csv
# Procesando día 2023-04-10…
#   → guardado: processed_by_date/cleaned_static_template_2023-04-10.pkl y processed_by_date/cleaned_static_template_2023-04-10.csv
# Procesando día 2023-04-11…
#   → guardado: processed_by_date/cleaned_static_template_2023-04-11.pkl y processed_by_date/cleaned_static_template_2023-04-11.csv
# Procesando día 2023-04-12…
#   → guardado: processed_by_date/cleaned_static_template_2023-04-12.pkl y processed_by_date/cleaned_static_template_2023-04-12.csv
# Procesando día 2023-04-13…
#   → guardado: processed_by_date/cleaned_static_template_2023-04-13.pkl y processed_by_date/cleaned_static_template_2023-04-13.csv
# Procesando día 2023-04-14…
#   → guardado: processed_by_date/cleaned_static_template_2023-04-14.pkl y processed_by_date/cleaned_static_template_2023-04-14.csv
# Procesando día 2023-04-15…
#   → guardado: processed_by_date/cleaned_static_template_2023-04-15.pkl y processed_by_date/cleaned_static_template_2023-04-15.csv
# Procesando día 2023-04-17…
#   → guardado: processed_by_date/cleaned_static_template_2023-04-17.pkl y processed_by_date/cleaned_static_template_2023-04-17.csv
# Procesando día 2023-04-18…
#   → guardado: processed_by_date/cleaned_static_template_2023-04-18.pkl y processed_by_date/cleaned_static_template_2023-04-18.csv
# Procesando día 2023-04-19…
#   → guardado: processed_by_date/cleaned_static_template_2023-04-19.pkl y processed_by_date/cleaned_static_template_2023-04-19.csv
# Procesando día 2023-04-20…
#   → guardado: processed_by_date/cleaned_static_template_2023-04-20.pkl y processed_by_date/cleaned_static_template_2023-04-20.csv
# Procesando día 2023-04-21…
#   → guardado: processed_by_date/cleaned_static_template_2023-04-21.pkl y processed_by_date/cleaned_static_template_2023-04-21.csv
# Procesando día 2023-04-22…
#   → guardado: processed_by_date/cleaned_static_template_2023-04-22.pkl y processed_by_date/cleaned_static_template_2023-04-22.csv
# Procesando día 2023-04-24…
#   → guardado: processed_by_date/cleaned_static_template_2023-04-24.pkl y processed_by_date/cleaned_static_template_2023-04-24.csv
# Procesando día 2023-04-25…
#   → guardado: processed_by_date/cleaned_static_template_2023-04-25.pkl y processed_by_date/cleaned_static_template_2023-04-25.csv
# Procesando día 2023-04-26…
#   → guardado: processed_by_date/cleaned_static_template_2023-04-26.pkl y processed_by_date/cleaned_static_template_2023-04-26.csv
# Procesando día 2023-04-27…
#   → guardado: processed_by_date/cleaned_static_template_2023-04-27.pkl y processed_by_date/cleaned_static_template_2023-04-27.csv
# Procesando día 2023-04-28…
#   → guardado: processed_by_date/cleaned_static_template_2023-04-28.pkl y processed_by_date/cleaned_static_template_2023-04-28.csv
# Procesando día 2023-04-29…
#   → guardado: processed_by_date/cleaned_static_template_2023-04-29.pkl y processed_by_date/cleaned_static_template_2023-04-29.csv
# Procesando día 2023-05-02…
#   → guardado: processed_by_date/cleaned_static_template_2023-05-02.pkl y processed_by_date/cleaned_static_template_2023-05-02.csv
# Procesando día 2023-05-03…
#   → guardado: processed_by_date/cleaned_static_template_2023-05-03.pkl y processed_by_date/cleaned_static_template_2023-05-03.csv
# Procesando día 2023-05-04…
#   → guardado: processed_by_date/cleaned_static_template_2023-05-04.pkl y processed_by_date/cleaned_static_template_2023-05-04.csv
# Procesando día 2023-05-05…
#   → guardado: processed_by_date/cleaned_static_template_2023-05-05.pkl y processed_by_date/cleaned_static_template_2023-05-05.csv
# Procesando día 2023-05-06…
#   → guardado: processed_by_date/cleaned_static_template_2023-05-06.pkl y processed_by_date/cleaned_static_template_2023-05-06.csv
# Procesando día 2023-05-08…
#   → guardado: processed_by_date/cleaned_static_template_2023-05-08.pkl y processed_by_date/cleaned_static_template_2023-05-08.csv
# Procesando día 2023-05-09…
#   → guardado: processed_by_date/cleaned_static_template_2023-05-09.pkl y processed_by_date/cleaned_static_template_2023-05-09.csv
# Procesando día 2023-05-10…
#   → guardado: processed_by_date/cleaned_static_template_2023-05-10.pkl y processed_by_date/cleaned_static_template_2023-05-10.csv
# Procesando día 2023-05-11…
#   → guardado: processed_by_date/cleaned_static_template_2023-05-11.pkl y processed_by_date/cleaned_static_template_2023-05-11.csv
# Procesando día 2023-05-12…
#   → guardado: processed_by_date/cleaned_static_template_2023-05-12.pkl y processed_by_date/cleaned_static_template_2023-05-12.csv
# Procesando día 2023-05-13…
#   → guardado: processed_by_date/cleaned_static_template_2023-05-13.pkl y processed_by_date/cleaned_static_template_2023-05-13.csv
# Procesando día 2023-05-15…
#   → guardado: processed_by_date/cleaned_static_template_2023-05-15.pkl y processed_by_date/cleaned_static_template_2023-05-15.csv
# Procesando día 2023-05-16…
#   → guardado: processed_by_date/cleaned_static_template_2023-05-16.pkl y processed_by_date/cleaned_static_template_2023-05-16.csv
# Procesando día 2023-05-17…
#   → guardado: processed_by_date/cleaned_static_template_2023-05-17.pkl y processed_by_date/cleaned_static_template_2023-05-17.csv
# Procesando día 2023-05-18…
#   → guardado: processed_by_date/cleaned_static_template_2023-05-18.pkl y processed_by_date/cleaned_static_template_2023-05-18.csv
# Procesando día 2023-05-19…
#   → guardado: processed_by_date/cleaned_static_template_2023-05-19.pkl y processed_by_date/cleaned_static_template_2023-05-19.csv
# Procesando día 2023-05-20…
#   → guardado: processed_by_date/cleaned_static_template_2023-05-20.pkl y processed_by_date/cleaned_static_template_2023-05-20.csv
# Procesando día 2023-05-21…
#   → No servicios válidos para 2023-05-21, saltando.
# Procesando día 2023-05-23…
#   → guardado: processed_by_date/cleaned_static_template_2023-05-23.pkl y processed_by_date/cleaned_static_template_2023-05-23.csv
# Procesando día 2023-05-24…
#   → guardado: processed_by_date/cleaned_static_template_2023-05-24.pkl y processed_by_date/cleaned_static_template_2023-05-24.csv
# Procesando día 2023-05-25…
#   → guardado: processed_by_date/cleaned_static_template_2023-05-25.pkl y processed_by_date/cleaned_static_template_2023-05-25.csv
# Procesando día 2023-05-26…
#   → guardado: processed_by_date/cleaned_static_template_2023-05-26.pkl y processed_by_date/cleaned_static_template_2023-05-26.csv
# Procesando día 2023-05-27…
#   → guardado: processed_by_date/cleaned_static_template_2023-05-27.pkl y processed_by_date/cleaned_static_template_2023-05-27.csv
# Procesando día 2023-05-28…
#   → No servicios válidos para 2023-05-28, saltando.
# Procesando día 2023-05-29…
#   → guardado: processed_by_date/cleaned_static_template_2023-05-29.pkl y processed_by_date/cleaned_static_template_2023-05-29.csv
# Procesando día 2023-05-30…
#   → guardado: processed_by_date/cleaned_static_template_2023-05-30.pkl y processed_by_date/cleaned_static_template_2023-05-30.csv
# Procesando día 2023-05-31…
#   → guardado: processed_by_date/cleaned_static_template_2023-05-31.pkl y processed_by_date/cleaned_static_template_2023-05-31.csv
# Procesando día 2023-06-01…
#   → guardado: processed_by_date/cleaned_static_template_2023-06-01.pkl y processed_by_date/cleaned_static_template_2023-06-01.csv
# Procesando día 2023-06-02…
#   → guardado: processed_by_date/cleaned_static_template_2023-06-02.pkl y processed_by_date/cleaned_static_template_2023-06-02.csv
# Procesando día 2023-06-03…
#   → guardado: processed_by_date/cleaned_static_template_2023-06-03.pkl y processed_by_date/cleaned_static_template_2023-06-03.csv
# Procesando día 2023-06-04…
#   → No servicios válidos para 2023-06-04, saltando.
# Procesando día 2023-06-05…
#   → guardado: processed_by_date/cleaned_static_template_2023-06-05.pkl y processed_by_date/cleaned_static_template_2023-06-05.csv
# Procesando día 2023-06-06…
#   → guardado: processed_by_date/cleaned_static_template_2023-06-06.pkl y processed_by_date/cleaned_static_template_2023-06-06.csv
# Procesando día 2023-06-07…
#   → guardado: processed_by_date/cleaned_static_template_2023-06-07.pkl y processed_by_date/cleaned_static_template_2023-06-07.csv
# Procesando día 2023-06-08…
#   → guardado: processed_by_date/cleaned_static_template_2023-06-08.pkl y processed_by_date/cleaned_static_template_2023-06-08.csv
# Procesando día 2023-06-09…
#   → guardado: processed_by_date/cleaned_static_template_2023-06-09.pkl y processed_by_date/cleaned_static_template_2023-06-09.csv
# Procesando día 2023-06-10…
#   → guardado: processed_by_date/cleaned_static_template_2023-06-10.pkl y processed_by_date/cleaned_static_template_2023-06-10.csv
# Procesando día 2023-06-11…
#   → No servicios válidos para 2023-06-11, saltando.
# Procesando día 2023-06-13…
#   → guardado: processed_by_date/cleaned_static_template_2023-06-13.pkl y processed_by_date/cleaned_static_template_2023-06-13.csv
# Procesando día 2023-06-14…
#   → guardado: processed_by_date/cleaned_static_template_2023-06-14.pkl y processed_by_date/cleaned_static_template_2023-06-14.csv
# Procesando día 2023-06-15…
#   → guardado: processed_by_date/cleaned_static_template_2023-06-15.pkl y processed_by_date/cleaned_static_template_2023-06-15.csv
# Procesando día 2023-06-16…
#   → guardado: processed_by_date/cleaned_static_template_2023-06-16.pkl y processed_by_date/cleaned_static_template_2023-06-16.csv
# Procesando día 2023-06-17…
#   → guardado: processed_by_date/cleaned_static_template_2023-06-17.pkl y processed_by_date/cleaned_static_template_2023-06-17.csv
# Procesando día 2023-06-18…
#   → No servicios válidos para 2023-06-18, saltando.
# Procesando día 2023-06-20…
#   → guardado: processed_by_date/cleaned_static_template_2023-06-20.pkl y processed_by_date/cleaned_static_template_2023-06-20.csv
# Procesando día 2023-06-21…
#   → guardado: processed_by_date/cleaned_static_template_2023-06-21.pkl y processed_by_date/cleaned_static_template_2023-06-21.csv
# Procesando día 2023-06-22…
#   → guardado: processed_by_date/cleaned_static_template_2023-06-22.pkl y processed_by_date/cleaned_static_template_2023-06-22.csv
# Procesando día 2023-06-23…
#   → guardado: processed_by_date/cleaned_static_template_2023-06-23.pkl y processed_by_date/cleaned_static_template_2023-06-23.csv
# Procesando día 2023-06-24…
#   → guardado: processed_by_date/cleaned_static_template_2023-06-24.pkl y processed_by_date/cleaned_static_template_2023-06-24.csv
# Procesando día 2023-06-25…
#   → No servicios válidos para 2023-06-25, saltando.
# Procesando día 2023-06-26…
#   → guardado: processed_by_date/cleaned_static_template_2023-06-26.pkl y processed_by_date/cleaned_static_template_2023-06-26.csv
# Procesando día 2023-06-27…
#   → guardado: processed_by_date/cleaned_static_template_2023-06-27.pkl y processed_by_date/cleaned_static_template_2023-06-27.csv
# Procesando día 2023-06-28…
#   → guardado: processed_by_date/cleaned_static_template_2023-06-28.pkl y processed_by_date/cleaned_static_template_2023-06-28.csv
# Procesando día 2023-06-29…
#   → guardado: processed_by_date/cleaned_static_template_2023-06-29.pkl y processed_by_date/cleaned_static_template_2023-06-29.csv
# Procesando día 2023-06-30…
#   → guardado: processed_by_date/cleaned_static_template_2023-06-30.pkl y processed_by_date/cleaned_static_template_2023-06-30.csv
# Procesando día 2023-07-01…
#   → guardado: processed_by_date/cleaned_static_template_2023-07-01.pkl y processed_by_date/cleaned_static_template_2023-07-01.csv
# Procesando día 2023-07-04…
#   → guardado: processed_by_date/cleaned_static_template_2023-07-04.pkl y processed_by_date/cleaned_static_template_2023-07-04.csv
# Procesando día 2023-07-05…
#   → guardado: processed_by_date/cleaned_static_template_2023-07-05.pkl y processed_by_date/cleaned_static_template_2023-07-05.csv
# Procesando día 2023-07-06…
#   → guardado: processed_by_date/cleaned_static_template_2023-07-06.pkl y processed_by_date/cleaned_static_template_2023-07-06.csv
# Procesando día 2023-07-07…
#   → guardado: processed_by_date/cleaned_static_template_2023-07-07.pkl y processed_by_date/cleaned_static_template_2023-07-07.csv
# Procesando día 2023-07-08…
#   → guardado: processed_by_date/cleaned_static_template_2023-07-08.pkl y processed_by_date/cleaned_static_template_2023-07-08.csv
# Procesando día 2023-07-09…
#   → No servicios válidos para 2023-07-09, saltando.
# Procesando día 2023-07-10…
#   → guardado: processed_by_date/cleaned_static_template_2023-07-10.pkl y processed_by_date/cleaned_static_template_2023-07-10.csv
# Procesando día 2023-07-11…
#   → guardado: processed_by_date/cleaned_static_template_2023-07-11.pkl y processed_by_date/cleaned_static_template_2023-07-11.csv
# Procesando día 2023-07-12…
#   → guardado: processed_by_date/cleaned_static_template_2023-07-12.pkl y processed_by_date/cleaned_static_template_2023-07-12.csv
# Procesando día 2023-07-13…
#   → guardado: processed_by_date/cleaned_static_template_2023-07-13.pkl y processed_by_date/cleaned_static_template_2023-07-13.csv
# Procesando día 2023-07-14…
#   → guardado: processed_by_date/cleaned_static_template_2023-07-14.pkl y processed_by_date/cleaned_static_template_2023-07-14.csv
# Procesando día 2023-07-15…
#   → guardado: processed_by_date/cleaned_static_template_2023-07-15.pkl y processed_by_date/cleaned_static_template_2023-07-15.csv
# Procesando día 2023-07-16…
#   → No servicios válidos para 2023-07-16, saltando.
# Procesando día 2023-07-17…
#   → guardado: processed_by_date/cleaned_static_template_2023-07-17.pkl y processed_by_date/cleaned_static_template_2023-07-17.csv
# Procesando día 2023-07-18…
#   → guardado: processed_by_date/cleaned_static_template_2023-07-18.pkl y processed_by_date/cleaned_static_template_2023-07-18.csv
# Procesando día 2023-07-19…
#   → guardado: processed_by_date/cleaned_static_template_2023-07-19.pkl y processed_by_date/cleaned_static_template_2023-07-19.csv
# Procesando día 2023-07-20…
#   → No servicios válidos para 2023-07-20, saltando.
# Procesando día 2023-07-21…
#   → guardado: processed_by_date/cleaned_static_template_2023-07-21.pkl y processed_by_date/cleaned_static_template_2023-07-21.csv
# Procesando día 2023-07-22…
#   → guardado: processed_by_date/cleaned_static_template_2023-07-22.pkl y processed_by_date/cleaned_static_template_2023-07-22.csv
# Procesando día 2023-07-23…
#   → No servicios válidos para 2023-07-23, saltando.
# Procesando día 2023-07-24…
#   → guardado: processed_by_date/cleaned_static_template_2023-07-24.pkl y processed_by_date/cleaned_static_template_2023-07-24.csv
# Procesando día 2023-07-25…
#   → guardado: processed_by_date/cleaned_static_template_2023-07-25.pkl y processed_by_date/cleaned_static_template_2023-07-25.csv
# Procesando día 2023-07-26…
#   → guardado: processed_by_date/cleaned_static_template_2023-07-26.pkl y processed_by_date/cleaned_static_template_2023-07-26.csv
# Procesando día 2023-07-27…
#   → guardado: processed_by_date/cleaned_static_template_2023-07-27.pkl y processed_by_date/cleaned_static_template_2023-07-27.csv
# Procesando día 2023-07-28…
#   → guardado: processed_by_date/cleaned_static_template_2023-07-28.pkl y processed_by_date/cleaned_static_template_2023-07-28.csv
# Procesando día 2023-07-29…
#   → guardado: processed_by_date/cleaned_static_template_2023-07-29.pkl y processed_by_date/cleaned_static_template_2023-07-29.csv
# Procesando día 2023-07-30…
#   → No servicios válidos para 2023-07-30, saltando.
# Procesando día 2023-07-31…
#   → guardado: processed_by_date/cleaned_static_template_2023-07-31.pkl y processed_by_date/cleaned_static_template_2023-07-31.csv
# Procesando día 2023-08-01…
#   → guardado: processed_by_date/cleaned_static_template_2023-08-01.pkl y processed_by_date/cleaned_static_template_2023-08-01.csv
# Procesando día 2023-08-02…
#   → guardado: processed_by_date/cleaned_static_template_2023-08-02.pkl y processed_by_date/cleaned_static_template_2023-08-02.csv
# Procesando día 2023-08-03…
#   → guardado: processed_by_date/cleaned_static_template_2023-08-03.pkl y processed_by_date/cleaned_static_template_2023-08-03.csv
# Procesando día 2023-08-04…
#   → guardado: processed_by_date/cleaned_static_template_2023-08-04.pkl y processed_by_date/cleaned_static_template_2023-08-04.csv
# Procesando día 2023-08-05…
#   → guardado: processed_by_date/cleaned_static_template_2023-08-05.pkl y processed_by_date/cleaned_static_template_2023-08-05.csv
# Procesando día 2023-08-06…
#   → No servicios válidos para 2023-08-06, saltando.
# Procesando día 2023-08-08…
#   → guardado: processed_by_date/cleaned_static_template_2023-08-08.pkl y processed_by_date/cleaned_static_template_2023-08-08.csv
# Procesando día 2023-08-09…
#   → guardado: processed_by_date/cleaned_static_template_2023-08-09.pkl y processed_by_date/cleaned_static_template_2023-08-09.csv
# Procesando día 2023-08-10…
#   → guardado: processed_by_date/cleaned_static_template_2023-08-10.pkl y processed_by_date/cleaned_static_template_2023-08-10.csv
# Procesando día 2023-08-11…
#   → guardado: processed_by_date/cleaned_static_template_2023-08-11.pkl y processed_by_date/cleaned_static_template_2023-08-11.csv
# Procesando día 2023-08-12…
#   → guardado: processed_by_date/cleaned_static_template_2023-08-12.pkl y processed_by_date/cleaned_static_template_2023-08-12.csv
# Procesando día 2023-08-13…
#   → No servicios válidos para 2023-08-13, saltando.
# Procesando día 2023-08-14…
#   → guardado: processed_by_date/cleaned_static_template_2023-08-14.pkl y processed_by_date/cleaned_static_template_2023-08-14.csv
# Procesando día 2023-08-15…
#   → guardado: processed_by_date/cleaned_static_template_2023-08-15.pkl y processed_by_date/cleaned_static_template_2023-08-15.csv
# Procesando día 2023-08-16…
#   → guardado: processed_by_date/cleaned_static_template_2023-08-16.pkl y processed_by_date/cleaned_static_template_2023-08-16.csv
# Procesando día 2023-08-17…
#   → guardado: processed_by_date/cleaned_static_template_2023-08-17.pkl y processed_by_date/cleaned_static_template_2023-08-17.csv
# Procesando día 2023-08-18…
#   → guardado: processed_by_date/cleaned_static_template_2023-08-18.pkl y processed_by_date/cleaned_static_template_2023-08-18.csv
# Procesando día 2023-08-19…
#   → guardado: processed_by_date/cleaned_static_template_2023-08-19.pkl y processed_by_date/cleaned_static_template_2023-08-19.csv
# Procesando día 2023-08-20…
#   → No servicios válidos para 2023-08-20, saltando.
# Procesando día 2023-08-21…
#   → guardado: processed_by_date/cleaned_static_template_2023-08-21.pkl y processed_by_date/cleaned_static_template_2023-08-21.csv
# Procesando día 2023-08-22…
#   → guardado: processed_by_date/cleaned_static_template_2023-08-22.pkl y processed_by_date/cleaned_static_template_2023-08-22.csv
# Procesando día 2023-08-23…
#   → guardado: processed_by_date/cleaned_static_template_2023-08-23.pkl y processed_by_date/cleaned_static_template_2023-08-23.csv
# Procesando día 2023-08-24…
#   → guardado: processed_by_date/cleaned_static_template_2023-08-24.pkl y processed_by_date/cleaned_static_template_2023-08-24.csv
# Procesando día 2023-08-25…
#   → guardado: processed_by_date/cleaned_static_template_2023-08-25.pkl y processed_by_date/cleaned_static_template_2023-08-25.csv
# Procesando día 2023-08-26…
#   → guardado: processed_by_date/cleaned_static_template_2023-08-26.pkl y processed_by_date/cleaned_static_template_2023-08-26.csv
# Procesando día 2023-08-27…
#   → No servicios válidos para 2023-08-27, saltando.
# Procesando día 2023-08-28…
#   → guardado: processed_by_date/cleaned_static_template_2023-08-28.pkl y processed_by_date/cleaned_static_template_2023-08-28.csv
# Procesando día 2023-08-29…
#   → guardado: processed_by_date/cleaned_static_template_2023-08-29.pkl y processed_by_date/cleaned_static_template_2023-08-29.csv
# Procesando día 2023-08-30…
#   → guardado: processed_by_date/cleaned_static_template_2023-08-30.pkl y processed_by_date/cleaned_static_template_2023-08-30.csv
# Procesando día 2023-08-31…
#   → guardado: processed_by_date/cleaned_static_template_2023-08-31.pkl y processed_by_date/cleaned_static_template_2023-08-31.csv
# Procesando día 2023-09-01…
#   → guardado: processed_by_date/cleaned_static_template_2023-09-01.pkl y processed_by_date/cleaned_static_template_2023-09-01.csv
# Procesando día 2023-09-02…
#   → guardado: processed_by_date/cleaned_static_template_2023-09-02.pkl y processed_by_date/cleaned_static_template_2023-09-02.csv
# Procesando día 2023-09-03…
#   → No servicios válidos para 2023-09-03, saltando.
# Procesando día 2023-09-04…
#   → guardado: processed_by_date/cleaned_static_template_2023-09-04.pkl y processed_by_date/cleaned_static_template_2023-09-04.csv
# Procesando día 2023-09-05…
#   → guardado: processed_by_date/cleaned_static_template_2023-09-05.pkl y processed_by_date/cleaned_static_template_2023-09-05.csv
# Procesando día 2023-09-06…
#   → guardado: processed_by_date/cleaned_static_template_2023-09-06.pkl y processed_by_date/cleaned_static_template_2023-09-06.csv
# Procesando día 2023-09-07…
#   → guardado: processed_by_date/cleaned_static_template_2023-09-07.pkl y processed_by_date/cleaned_static_template_2023-09-07.csv
# Procesando día 2023-09-08…
#   → guardado: processed_by_date/cleaned_static_template_2023-09-08.pkl y processed_by_date/cleaned_static_template_2023-09-08.csv
# Procesando día 2023-09-09…
#   → guardado: processed_by_date/cleaned_static_template_2023-09-09.pkl y processed_by_date/cleaned_static_template_2023-09-09.csv
# Procesando día 2023-09-10…
#   → No servicios válidos para 2023-09-10, saltando.
# Procesando día 2023-09-11…
#   → guardado: processed_by_date/cleaned_static_template_2023-09-11.pkl y processed_by_date/cleaned_static_template_2023-09-11.csv
# Procesando día 2023-09-12…
#   → guardado: processed_by_date/cleaned_static_template_2023-09-12.pkl y processed_by_date/cleaned_static_template_2023-09-12.csv
# Procesando día 2023-09-13…
#   → guardado: processed_by_date/cleaned_static_template_2023-09-13.pkl y processed_by_date/cleaned_static_template_2023-09-13.csv
# Procesando día 2023-09-14…
#   → guardado: processed_by_date/cleaned_static_template_2023-09-14.pkl y processed_by_date/cleaned_static_template_2023-09-14.csv
# Procesando día 2023-09-15…
#   → guardado: processed_by_date/cleaned_static_template_2023-09-15.pkl y processed_by_date/cleaned_static_template_2023-09-15.csv
# Procesando día 2023-09-16…
#   → guardado: processed_by_date/cleaned_static_template_2023-09-16.pkl y processed_by_date/cleaned_static_template_2023-09-16.csv
# Procesando día 2023-09-17…
#   → No servicios válidos para 2023-09-17, saltando.
# Procesando día 2023-09-18…
#   → guardado: processed_by_date/cleaned_static_template_2023-09-18.pkl y processed_by_date/cleaned_static_template_2023-09-18.csv
# Procesando día 2023-09-19…
#   → guardado: processed_by_date/cleaned_static_template_2023-09-19.pkl y processed_by_date/cleaned_static_template_2023-09-19.csv
# Procesando día 2023-09-20…
#   → guardado: processed_by_date/cleaned_static_template_2023-09-20.pkl y processed_by_date/cleaned_static_template_2023-09-20.csv
# Procesando día 2023-09-21…
#   → guardado: processed_by_date/cleaned_static_template_2023-09-21.pkl y processed_by_date/cleaned_static_template_2023-09-21.csv
# Procesando día 2023-09-22…
#   → guardado: processed_by_date/cleaned_static_template_2023-09-22.pkl y processed_by_date/cleaned_static_template_2023-09-22.csv
# Procesando día 2023-09-23…
#   → guardado: processed_by_date/cleaned_static_template_2023-09-23.pkl y processed_by_date/cleaned_static_template_2023-09-23.csv
# Procesando día 2023-09-24…
#   → No servicios válidos para 2023-09-24, saltando.
# Procesando día 2023-09-25…
#   → guardado: processed_by_date/cleaned_static_template_2023-09-25.pkl y processed_by_date/cleaned_static_template_2023-09-25.csv
# Procesando día 2023-09-26…
#   → guardado: processed_by_date/cleaned_static_template_2023-09-26.pkl y processed_by_date/cleaned_static_template_2023-09-26.csv
# Procesando día 2023-09-27…
#   → guardado: processed_by_date/cleaned_static_template_2023-09-27.pkl y processed_by_date/cleaned_static_template_2023-09-27.csv
# Procesando día 2023-09-28…
#   → guardado: processed_by_date/cleaned_static_template_2023-09-28.pkl y processed_by_date/cleaned_static_template_2023-09-28.csv
# Procesando día 2023-09-29…
#   → guardado: processed_by_date/cleaned_static_template_2023-09-29.pkl y processed_by_date/cleaned_static_template_2023-09-29.csv
# Procesando día 2023-09-30…
#   → guardado: processed_by_date/cleaned_static_template_2023-09-30.pkl y processed_by_date/cleaned_static_template_2023-09-30.csv
# Procesando día 2023-10-01…
#   → No servicios válidos para 2023-10-01, saltando.
# Procesando día 2023-10-02…
#   → guardado: processed_by_date/cleaned_static_template_2023-10-02.pkl y processed_by_date/cleaned_static_template_2023-10-02.csv
# Procesando día 2023-10-03…
#   → guardado: processed_by_date/cleaned_static_template_2023-10-03.pkl y processed_by_date/cleaned_static_template_2023-10-03.csv
# Procesando día 2023-10-04…
#   → guardado: processed_by_date/cleaned_static_template_2023-10-04.pkl y processed_by_date/cleaned_static_template_2023-10-04.csv
# Procesando día 2023-10-05…
#   → guardado: processed_by_date/cleaned_static_template_2023-10-05.pkl y processed_by_date/cleaned_static_template_2023-10-05.csv
# Procesando día 2023-10-06…
#   → guardado: processed_by_date/cleaned_static_template_2023-10-06.pkl y processed_by_date/cleaned_static_template_2023-10-06.csv
# Procesando día 2023-10-07…
#   → guardado: processed_by_date/cleaned_static_template_2023-10-07.pkl y processed_by_date/cleaned_static_template_2023-10-07.csv
# Procesando día 2023-10-08…
#   → No servicios válidos para 2023-10-08, saltando.
# Procesando día 2023-10-09…
#   → guardado: processed_by_date/cleaned_static_template_2023-10-09.pkl y processed_by_date/cleaned_static_template_2023-10-09.csv
# Procesando día 2023-10-10…
#   → guardado: processed_by_date/cleaned_static_template_2023-10-10.pkl y processed_by_date/cleaned_static_template_2023-10-10.csv
# Procesando día 2023-10-11…
#   → guardado: processed_by_date/cleaned_static_template_2023-10-11.pkl y processed_by_date/cleaned_static_template_2023-10-11.csv
# Procesando día 2023-10-12…
#   → guardado: processed_by_date/cleaned_static_template_2023-10-12.pkl y processed_by_date/cleaned_static_template_2023-10-12.csv
# Procesando día 2023-10-13…
#   → guardado: processed_by_date/cleaned_static_template_2023-10-13.pkl y processed_by_date/cleaned_static_template_2023-10-13.csv
# Procesando día 2023-10-14…
#   → guardado: processed_by_date/cleaned_static_template_2023-10-14.pkl y processed_by_date/cleaned_static_template_2023-10-14.csv
# Procesando día 2023-10-15…
#   → No servicios válidos para 2023-10-15, saltando.
# Procesando día 2023-10-16…
#   → guardado: processed_by_date/cleaned_static_template_2023-10-16.pkl y processed_by_date/cleaned_static_template_2023-10-16.csv
# Procesando día 2023-10-17…
#   → guardado: processed_by_date/cleaned_static_template_2023-10-17.pkl y processed_by_date/cleaned_static_template_2023-10-17.csv
# Procesando día 2023-10-18…
#   → guardado: processed_by_date/cleaned_static_template_2023-10-18.pkl y processed_by_date/cleaned_static_template_2023-10-18.csv
# Procesando día 2023-10-19…
#   → guardado: processed_by_date/cleaned_static_template_2023-10-19.pkl y processed_by_date/cleaned_static_template_2023-10-19.csv
# Procesando día 2023-10-20…
#   → guardado: processed_by_date/cleaned_static_template_2023-10-20.pkl y processed_by_date/cleaned_static_template_2023-10-20.csv
# Procesando día 2023-10-21…
#   → guardado: processed_by_date/cleaned_static_template_2023-10-21.pkl y processed_by_date/cleaned_static_template_2023-10-21.csv
# Procesando día 2023-10-22…
#   → No servicios válidos para 2023-10-22, saltando.
# Procesando día 2023-10-23…
#   → guardado: processed_by_date/cleaned_static_template_2023-10-23.pkl y processed_by_date/cleaned_static_template_2023-10-23.csv
# Procesando día 2023-10-24…
#   → guardado: processed_by_date/cleaned_static_template_2023-10-24.pkl y processed_by_date/cleaned_static_template_2023-10-24.csv
# Procesando día 2023-10-25…
#   → guardado: processed_by_date/cleaned_static_template_2023-10-25.pkl y processed_by_date/cleaned_static_template_2023-10-25.csv
# Procesando día 2023-10-26…
#   → guardado: processed_by_date/cleaned_static_template_2023-10-26.pkl y processed_by_date/cleaned_static_template_2023-10-26.csv
# Procesando día 2023-10-27…
#   → guardado: processed_by_date/cleaned_static_template_2023-10-27.pkl y processed_by_date/cleaned_static_template_2023-10-27.csv
# Procesando día 2023-10-28…
#   → guardado: processed_by_date/cleaned_static_template_2023-10-28.pkl y processed_by_date/cleaned_static_template_2023-10-28.csv
# Procesando día 2023-10-29…
#   → No servicios válidos para 2023-10-29, saltando.
# Procesando día 2023-10-30…
#   → guardado: processed_by_date/cleaned_static_template_2023-10-30.pkl y processed_by_date/cleaned_static_template_2023-10-30.csv
# Procesando día 2023-10-31…
#   → guardado: processed_by_date/cleaned_static_template_2023-10-31.pkl y processed_by_date/cleaned_static_template_2023-10-31.csv
# Procesando día 2023-11-01…
#   → guardado: processed_by_date/cleaned_static_template_2023-11-01.pkl y processed_by_date/cleaned_static_template_2023-11-01.csv
# Procesando día 2023-11-02…
#   → guardado: processed_by_date/cleaned_static_template_2023-11-02.pkl y processed_by_date/cleaned_static_template_2023-11-02.csv
# Procesando día 2023-11-03…
#   → guardado: processed_by_date/cleaned_static_template_2023-11-03.pkl y processed_by_date/cleaned_static_template_2023-11-03.csv
# Procesando día 2023-11-04…
#   → guardado: processed_by_date/cleaned_static_template_2023-11-04.pkl y processed_by_date/cleaned_static_template_2023-11-04.csv
# Procesando día 2023-11-05…
#   → guardado: processed_by_date/cleaned_static_template_2023-11-05.pkl y processed_by_date/cleaned_static_template_2023-11-05.csv
# Procesando día 2023-11-06…
#   → guardado: processed_by_date/cleaned_static_template_2023-11-06.pkl y processed_by_date/cleaned_static_template_2023-11-06.csv
# Procesando día 2023-11-07…
#   → guardado: processed_by_date/cleaned_static_template_2023-11-07.pkl y processed_by_date/cleaned_static_template_2023-11-07.csv
# Procesando día 2023-11-08…
#   → guardado: processed_by_date/cleaned_static_template_2023-11-08.pkl y processed_by_date/cleaned_static_template_2023-11-08.csv
# Procesando día 2023-11-09…
#   → guardado: processed_by_date/cleaned_static_template_2023-11-09.pkl y processed_by_date/cleaned_static_template_2023-11-09.csv
# Procesando día 2023-11-10…
#   → guardado: processed_by_date/cleaned_static_template_2023-11-10.pkl y processed_by_date/cleaned_static_template_2023-11-10.csv
# Procesando día 2023-11-11…
#   → guardado: processed_by_date/cleaned_static_template_2023-11-11.pkl y processed_by_date/cleaned_static_template_2023-11-11.csv
# Procesando día 2023-11-12…
#   → No servicios válidos para 2023-11-12, saltando.
# Procesando día 2023-11-13…
#   → No servicios válidos para 2023-11-13, saltando.
# Procesando día 2023-11-14…
#   → guardado: processed_by_date/cleaned_static_template_2023-11-14.pkl y processed_by_date/cleaned_static_template_2023-11-14.csv
# Procesando día 2023-11-15…
#   → guardado: processed_by_date/cleaned_static_template_2023-11-15.pkl y processed_by_date/cleaned_static_template_2023-11-15.csv
# Procesando día 2023-11-16…
#   → guardado: processed_by_date/cleaned_static_template_2023-11-16.pkl y processed_by_date/cleaned_static_template_2023-11-16.csv
# Procesando día 2023-11-17…
#   → guardado: processed_by_date/cleaned_static_template_2023-11-17.pkl y processed_by_date/cleaned_static_template_2023-11-17.csv
# Procesando día 2023-11-18…
#   → guardado: processed_by_date/cleaned_static_template_2023-11-18.pkl y processed_by_date/cleaned_static_template_2023-11-18.csv
# Procesando día 2023-11-19…
#   → No servicios válidos para 2023-11-19, saltando.
# Procesando día 2023-11-20…
#   → guardado: processed_by_date/cleaned_static_template_2023-11-20.pkl y processed_by_date/cleaned_static_template_2023-11-20.csv
# Procesando día 2023-11-21…
#   → guardado: processed_by_date/cleaned_static_template_2023-11-21.pkl y processed_by_date/cleaned_static_template_2023-11-21.csv
# Procesando día 2023-11-22…
#   → guardado: processed_by_date/cleaned_static_template_2023-11-22.pkl y processed_by_date/cleaned_static_template_2023-11-22.csv
# Procesando día 2023-11-23…
#   → guardado: processed_by_date/cleaned_static_template_2023-11-23.pkl y processed_by_date/cleaned_static_template_2023-11-23.csv
# Procesando día 2023-11-24…
#   → guardado: processed_by_date/cleaned_static_template_2023-11-24.pkl y processed_by_date/cleaned_static_template_2023-11-24.csv
# Procesando día 2023-11-25…
#   → guardado: processed_by_date/cleaned_static_template_2023-11-25.pkl y processed_by_date/cleaned_static_template_2023-11-25.csv
# Procesando día 2023-11-26…
#   → No servicios válidos para 2023-11-26, saltando.
# Procesando día 2023-11-27…
#   → guardado: processed_by_date/cleaned_static_template_2023-11-27.pkl y processed_by_date/cleaned_static_template_2023-11-27.csv
# Procesando día 2023-11-28…
#   → guardado: processed_by_date/cleaned_static_template_2023-11-28.pkl y processed_by_date/cleaned_static_template_2023-11-28.csv
# Procesando día 2023-11-29…
#   → guardado: processed_by_date/cleaned_static_template_2023-11-29.pkl y processed_by_date/cleaned_static_template_2023-11-29.csv
# Procesando día 2023-11-30…
#   → guardado: processed_by_date/cleaned_static_template_2023-11-30.pkl y processed_by_date/cleaned_static_template_2023-11-30.csv
# Procesando día 2023-12-01…
#   → guardado: processed_by_date/cleaned_static_template_2023-12-01.pkl y processed_by_date/cleaned_static_template_2023-12-01.csv
# Procesando día 2023-12-02…
#   → guardado: processed_by_date/cleaned_static_template_2023-12-02.pkl y processed_by_date/cleaned_static_template_2023-12-02.csv
# Procesando día 2023-12-03…
#   → No servicios válidos para 2023-12-03, saltando.
# Procesando día 2023-12-04…
#   → guardado: processed_by_date/cleaned_static_template_2023-12-04.pkl y processed_by_date/cleaned_static_template_2023-12-04.csv
# Procesando día 2023-12-05…
#   → guardado: processed_by_date/cleaned_static_template_2023-12-05.pkl y processed_by_date/cleaned_static_template_2023-12-05.csv
# Procesando día 2023-12-06…
#   → guardado: processed_by_date/cleaned_static_template_2023-12-06.pkl y processed_by_date/cleaned_static_template_2023-12-06.csv
# Procesando día 2023-12-07…
#   → guardado: processed_by_date/cleaned_static_template_2023-12-07.pkl y processed_by_date/cleaned_static_template_2023-12-07.csv
# Procesando día 2023-12-08…
#   → guardado: processed_by_date/cleaned_static_template_2023-12-08.pkl y processed_by_date/cleaned_static_template_2023-12-08.csv
# Procesando día 2023-12-09…
#   → guardado: processed_by_date/cleaned_static_template_2023-12-09.pkl y processed_by_date/cleaned_static_template_2023-12-09.csv
# Procesando día 2023-12-10…
#   → No servicios válidos para 2023-12-10, saltando.
# Procesando día 2023-12-11…
#   → guardado: processed_by_date/cleaned_static_template_2023-12-11.pkl y processed_by_date/cleaned_static_template_2023-12-11.csv
# Procesando día 2023-12-12…
#   → guardado: processed_by_date/cleaned_static_template_2023-12-12.pkl y processed_by_date/cleaned_static_template_2023-12-12.csv
# Procesando día 2023-12-13…
#   → guardado: processed_by_date/cleaned_static_template_2023-12-13.pkl y processed_by_date/cleaned_static_template_2023-12-13.csv
# Procesando día 2023-12-14…
#   → guardado: processed_by_date/cleaned_static_template_2023-12-14.pkl y processed_by_date/cleaned_static_template_2023-12-14.csv
# Procesando día 2023-12-15…
#   → guardado: processed_by_date/cleaned_static_template_2023-12-15.pkl y processed_by_date/cleaned_static_template_2023-12-15.csv
# Procesando día 2023-12-16…
#   → guardado: processed_by_date/cleaned_static_template_2023-12-16.pkl y processed_by_date/cleaned_static_template_2023-12-16.csv
# Procesando día 2023-12-17…
#   → No servicios válidos para 2023-12-17, saltando.
# Procesando día 2023-12-18…
#   → guardado: processed_by_date/cleaned_static_template_2023-12-18.pkl y processed_by_date/cleaned_static_template_2023-12-18.csv
# ...
# Procesando día 2025-02-18…
#   → guardado: processed_by_date/cleaned_static_template_2025-02-18.pkl y processed_by_date/cleaned_static_template_2025-02-18.csv
# Procesando día 2025-02-19…
#   → guardado: processed_by_date/cleaned_static_template_2025-02-19.pkl y processed_by_date/cleaned_static_template_2025-02-19.csv
# Procesando día 2025-02-20…
#   → guardado: processed_by_date/cleaned_static_template_2025-02-20.pkl y processed_by_date/cleaned_static_template_2025-02-20.csv
# Procesando día 2025-02-21…
#   → guardado: processed_by_date/cleaned_static_template_2025-02-21.pkl y processed_by_date/cleaned_static_template_2025-02-21.csv
# Procesando día 2025-02-22…
#   → guardado: processed_by_date/cleaned_static_template_2025-02-22.pkl y processed_by_date/cleaned_static_template_2025-02-22.csv
# Procesando día 2025-02-23…
#   → No servicios válidos para 2025-02-23, saltando.
# Procesando día 2025-02-24…
#   → guardado: processed_by_date/cleaned_static_template_2025-02-24.pkl y processed_by_date/cleaned_static_template_2025-02-24.csv
# Procesando día 2025-02-25…
#   → guardado: processed_by_date/cleaned_static_template_2025-02-25.pkl y processed_by_date/cleaned_static_template_2025-02-25.csv
# Procesando día 2025-02-26…
#   → guardado: processed_by_date/cleaned_static_template_2025-02-26.pkl y processed_by_date/cleaned_static_template_2025-02-26.csv
# Procesando día 2025-02-27…
#   → guardado: processed_by_date/cleaned_static_template_2025-02-27.pkl y processed_by_date/cleaned_static_template_2025-02-27.csv
# Procesando día 2025-02-28…
#   → guardado: processed_by_date/cleaned_static_template_2025-02-28.pkl y processed_by_date/cleaned_static_template_2025-02-28.csv
# Procesando día 2025-03-01…
#   → guardado: processed_by_date/cleaned_static_template_2025-03-01.pkl y processed_by_date/cleaned_static_template_2025-03-01.csv
# Procesando día 2025-03-02…
#   → No servicios válidos para 2025-03-02, saltando.
# Procesando día 2025-03-03…
#   → guardado: processed_by_date/cleaned_static_template_2025-03-03.pkl y processed_by_date/cleaned_static_template_2025-03-03.csv
# Procesando día 2025-03-04…
#   → guardado: processed_by_date/cleaned_static_template_2025-03-04.pkl y processed_by_date/cleaned_static_template_2025-03-04.csv
# Procesando día 2025-03-05…
#   → guardado: processed_by_date/cleaned_static_template_2025-03-05.pkl y processed_by_date/cleaned_static_template_2025-03-05.csv
# Procesando día 2025-03-06…
#   → guardado: processed_by_date/cleaned_static_template_2025-03-06.pkl y processed_by_date/cleaned_static_template_2025-03-06.csv
# Procesando día 2025-03-07…
#   → guardado: processed_by_date/cleaned_static_template_2025-03-07.pkl y processed_by_date/cleaned_static_template_2025-03-07.csv
# Procesando día 2025-03-08…
#   → guardado: processed_by_date/cleaned_static_template_2025-03-08.pkl y processed_by_date/cleaned_static_template_2025-03-08.csv
# Procesando día 2025-03-09…
#   → No servicios válidos para 2025-03-09, saltando.
# Procesando día 2025-03-10…
#   → guardado: processed_by_date/cleaned_static_template_2025-03-10.pkl y processed_by_date/cleaned_static_template_2025-03-10.csv
# Procesando día 2025-03-11…
#   → guardado: processed_by_date/cleaned_static_template_2025-03-11.pkl y processed_by_date/cleaned_static_template_2025-03-11.csv
# Procesando día 2025-03-12…
#   → guardado: processed_by_date/cleaned_static_template_2025-03-12.pkl y processed_by_date/cleaned_static_template_2025-03-12.csv
# Procesando día 2025-03-13…
#   → guardado: processed_by_date/cleaned_static_template_2025-03-13.pkl y processed_by_date/cleaned_static_template_2025-03-13.csv
# Procesando día 2025-03-14…
#   → guardado: processed_by_date/cleaned_static_template_2025-03-14.pkl y processed_by_date/cleaned_static_template_2025-03-14.csv
# Procesando día 2025-03-15…
#   → guardado: processed_by_date/cleaned_static_template_2025-03-15.pkl y processed_by_date/cleaned_static_template_2025-03-15.csv
# Procesando día 2025-03-16…
#   → No servicios válidos para 2025-03-16, saltando.
# Procesando día 2025-03-17…
#   → guardado: processed_by_date/cleaned_static_template_2025-03-17.pkl y processed_by_date/cleaned_static_template_2025-03-17.csv
# Procesando día 2025-03-18…
#   → guardado: processed_by_date/cleaned_static_template_2025-03-18.pkl y processed_by_date/cleaned_static_template_2025-03-18.csv
# Procesando día 2025-03-19…
#   → guardado: processed_by_date/cleaned_static_template_2025-03-19.pkl y processed_by_date/cleaned_static_template_2025-03-19.csv
# Procesando día 2025-03-20…
#   → guardado: processed_by_date/cleaned_static_template_2025-03-20.pkl y processed_by_date/cleaned_static_template_2025-03-20.csv
# Procesando día 2025-03-21…
#   → guardado: processed_by_date/cleaned_static_template_2025-03-21.pkl y processed_by_date/cleaned_static_template_2025-03-21.csv
# Procesando día 2025-03-22…
#   → guardado: processed_by_date/cleaned_static_template_2025-03-22.pkl y processed_by_date/cleaned_static_template_2025-03-22.csv
# Procesando día 2025-03-23…
#   → No servicios válidos para 2025-03-23, saltando.
# Procesando día 2025-03-24…
#   → No servicios válidos para 2025-03-24, saltando.
# Procesando día 2025-03-25…
#   → guardado: processed_by_date/cleaned_static_template_2025-03-25.pkl y processed_by_date/cleaned_static_template_2025-03-25.csv
# Procesando día 2025-03-26…
#   → guardado: processed_by_date/cleaned_static_template_2025-03-26.pkl y processed_by_date/cleaned_static_template_2025-03-26.csv
# Procesando día 2025-03-27…
#   → guardado: processed_by_date/cleaned_static_template_2025-03-27.pkl y processed_by_date/cleaned_static_template_2025-03-27.csv
# Procesando día 2025-03-28…
#   → guardado: processed_by_date/cleaned_static_template_2025-03-28.pkl y processed_by_date/cleaned_static_template_2025-03-28.csv
# Procesando día 2025-03-29…
#   → guardado: processed_by_date/cleaned_static_template_2025-03-29.pkl y processed_by_date/cleaned_static_template_2025-03-29.csv
# Procesando día 2025-03-30…
#   → No servicios válidos para 2025-03-30, saltando.
# Procesando día 2025-03-31…
#   → guardado: processed_by_date/cleaned_static_template_2025-03-31.pkl y processed_by_date/cleaned_static_template_2025-03-31.csv
# Procesando día 2025-04-01…
#   → guardado: processed_by_date/cleaned_static_template_2025-04-01.pkl y processed_by_date/cleaned_static_template_2025-04-01.csv
# Procesando día 2025-04-02…
#   → guardado: processed_by_date/cleaned_static_template_2025-04-02.pkl y processed_by_date/cleaned_static_template_2025-04-02.csv
# Procesando día 2025-04-03…
#   → guardado: processed_by_date/cleaned_static_template_2025-04-03.pkl y processed_by_date/cleaned_static_template_2025-04-03.csv
# Procesando día 2025-04-04…
#   → guardado: processed_by_date/cleaned_static_template_2025-04-04.pkl y processed_by_date/cleaned_static_template_2025-04-04.csv
# Procesando día 2025-04-05…
#   → guardado: processed_by_date/cleaned_static_template_2025-04-05.pkl y processed_by_date/cleaned_static_template_2025-04-05.csv
# Procesando día 2025-04-06…
#   → No servicios válidos para 2025-04-06, saltando.
# Procesando día 2025-04-07…
#   → guardado: processed_by_date/cleaned_static_template_2025-04-07.pkl y processed_by_date/cleaned_static_template_2025-04-07.csv
# Procesando día 2025-04-08…
#   → guardado: processed_by_date/cleaned_static_template_2025-04-08.pkl y processed_by_date/cleaned_static_template_2025-04-08.csv
# Procesando día 2025-04-09…
#   → guardado: processed_by_date/cleaned_static_template_2025-04-09.pkl y processed_by_date/cleaned_static_template_2025-04-09.csv
# Procesando día 2025-04-10…
#   → guardado: processed_by_date/cleaned_static_template_2025-04-10.pkl y processed_by_date/cleaned_static_template_2025-04-10.csv
# Procesando día 2025-04-11…
#   → guardado: processed_by_date/cleaned_static_template_2025-04-11.pkl y processed_by_date/cleaned_static_template_2025-04-11.csv
# Procesando día 2025-04-12…
#   → guardado: processed_by_date/cleaned_static_template_2025-04-12.pkl y processed_by_date/cleaned_static_template_2025-04-12.csv
# Procesando día 2025-04-13…
#   → No servicios válidos para 2025-04-13, saltando.
# Procesando día 2025-04-14…
#   → guardado: processed_by_date/cleaned_static_template_2025-04-14.pkl y processed_by_date/cleaned_static_template_2025-04-14.csv
# Procesando día 2025-04-15…
#   → guardado: processed_by_date/cleaned_static_template_2025-04-15.pkl y processed_by_date/cleaned_static_template_2025-04-15.csv
# Procesando día 2025-04-16…
#   → guardado: processed_by_date/cleaned_static_template_2025-04-16.pkl y processed_by_date/cleaned_static_template_2025-04-16.csv
# Procesando día 2025-04-17…
#   → No servicios válidos para 2025-04-17, saltando.
# Procesando día 2025-04-19…
#   → guardado: processed_by_date/cleaned_static_template_2025-04-19.pkl y processed_by_date/cleaned_static_template_2025-04-19.csv
# Procesando día 2025-04-20…
#   → No servicios válidos para 2025-04-20, saltando.
# Procesando día 2025-04-21…
#   → guardado: processed_by_date/cleaned_static_template_2025-04-21.pkl y processed_by_date/cleaned_static_template_2025-04-21.csv
# Procesando día 2025-04-22…
#   → guardado: processed_by_date/cleaned_static_template_2025-04-22.pkl y processed_by_date/cleaned_static_template_2025-04-22.csv
# Procesando día 2025-04-23…
#   → guardado: processed_by_date/cleaned_static_template_2025-04-23.pkl y processed_by_date/cleaned_static_template_2025-04-23.csv
# Procesando día 2025-04-24…
#   → guardado: processed_by_date/cleaned_static_template_2025-04-24.pkl y processed_by_date/cleaned_static_template_2025-04-24.csv
# Procesando día 2025-04-25…
#   → guardado: processed_by_date/cleaned_static_template_2025-04-25.pkl y processed_by_date/cleaned_static_template_2025-04-25.csv
# Procesando día 2025-04-26…
#   → guardado: processed_by_date/cleaned_static_template_2025-04-26.pkl y processed_by_date/cleaned_static_template_2025-04-26.csv
# Procesando día 2025-04-27…
#   → No servicios válidos para 2025-04-27, saltando.
# Procesando día 2025-04-28…
#   → guardado: processed_by_date/cleaned_static_template_2025-04-28.pkl y processed_by_date/cleaned_static_template_2025-04-28.csv
# Procesando día 2025-04-29…
#   → guardado: processed_by_date/cleaned_static_template_2025-04-29.pkl y processed_by_date/cleaned_static_template_2025-04-29.csv
# Procesando día 2025-04-30…
#   → guardado: processed_by_date/cleaned_static_template_2025-04-30.pkl y processed_by_date/cleaned_static_template_2025-04-30.csv
# Procesando día 2025-05-01…
#   → No servicios válidos para 2025-05-01, saltando.
# Procesando día 2025-05-02…
#   → guardado: processed_by_date/cleaned_static_template_2025-05-02.pkl y processed_by_date/cleaned_static_template_2025-05-02.csv
# Procesando día 2025-05-03…
#   → guardado: processed_by_date/cleaned_static_template_2025-05-03.pkl y processed_by_date/cleaned_static_template_2025-05-03.csv
# Procesando día 2025-05-04…
#   → No servicios válidos para 2025-05-04, saltando.
# Procesando día 2025-05-05…
#   → guardado: processed_by_date/cleaned_static_template_2025-05-05.pkl y processed_by_date/cleaned_static_template_2025-05-05.csv
# Procesando día 2025-05-06…
#   → guardado: processed_by_date/cleaned_static_template_2025-05-06.pkl y processed_by_date/cleaned_static_template_2025-05-06.csv
# Procesando día 2025-05-07…
#   → guardado: processed_by_date/cleaned_static_template_2025-05-07.pkl y processed_by_date/cleaned_static_template_2025-05-07.csv
# Procesando día 2025-05-08…
#   → guardado: processed_by_date/cleaned_static_template_2025-05-08.pkl y processed_by_date/cleaned_static_template_2025-05-08.csv
# Procesando día 2025-05-09…
#   → guardado: processed_by_date/cleaned_static_template_2025-05-09.pkl y processed_by_date/cleaned_static_template_2025-05-09.csv
# Procesando día 2025-05-10…
#   → guardado: processed_by_date/cleaned_static_template_2025-05-10.pkl y processed_by_date/cleaned_static_template_2025-05-10.csv
# Procesando día 2025-05-11…
#   → No servicios válidos para 2025-05-11, saltando.
# Procesando día 2025-05-12…
#   → guardado: processed_by_date/cleaned_static_template_2025-05-12.pkl y processed_by_date/cleaned_static_template_2025-05-12.csv
# Procesando día 2025-05-13…
#   → guardado: processed_by_date/cleaned_static_template_2025-05-13.pkl y processed_by_date/cleaned_static_template_2025-05-13.csv
# Procesando día 2025-05-14…
#   → guardado: processed_by_date/cleaned_static_template_2025-05-14.pkl y processed_by_date/cleaned_static_template_2025-05-14.csv
# Procesando día 2025-05-15…
#   → guardado: processed_by_date/cleaned_static_template_2025-05-15.pkl y processed_by_date/cleaned_static_template_2025-05-15.csv
# Procesando día 2025-05-16…
#   → guardado: processed_by_date/cleaned_static_template_2025-05-16.pkl y processed_by_date/cleaned_static_template_2025-05-16.csv
# Procesando día 2025-05-17…
#   → guardado: processed_by_date/cleaned_static_template_2025-05-17.pkl y processed_by_date/cleaned_static_template_2025-05-17.csv
# Procesando día 2025-05-18…
#   → No servicios válidos para 2025-05-18, saltando.
# Procesando día 2025-05-19…
#   → guardado: processed_by_date/cleaned_static_template_2025-05-19.pkl y processed_by_date/cleaned_static_template_2025-05-19.csv
# Procesando día 2025-05-20…
#   → guardado: processed_by_date/cleaned_static_template_2025-05-20.pkl y processed_by_date/cleaned_static_template_2025-05-20.csv
# Procesando día 2025-05-21…
#   → guardado: processed_by_date/cleaned_static_template_2025-05-21.pkl y processed_by_date/cleaned_static_template_2025-05-21.csv
# Procesando día 2025-05-22…
#   → guardado: processed_by_date/cleaned_static_template_2025-05-22.pkl y processed_by_date/cleaned_static_template_2025-05-22.csv
# Procesando día 2025-05-23…
#   → guardado: processed_by_date/cleaned_static_template_2025-05-23.pkl y processed_by_date/cleaned_static_template_2025-05-23.csv
# Procesando día 2025-05-24…
#   → guardado: processed_by_date/cleaned_static_template_2025-05-24.pkl y processed_by_date/cleaned_static_template_2025-05-24.csv
# Procesando día 2025-05-25…
#   → No servicios válidos para 2025-05-25, saltando.
# Procesando día 2025-05-26…
#   → guardado: processed_by_date/cleaned_static_template_2025-05-26.pkl y processed_by_date/cleaned_static_template_2025-05-26.csv
# Procesando día 2025-05-27…
#   → guardado: processed_by_date/cleaned_static_template_2025-05-27.pkl y processed_by_date/cleaned_static_template_2025-05-27.csv
# Procesando día 2025-05-28…
#   → guardado: processed_by_date/cleaned_static_template_2025-05-28.pkl y processed_by_date/cleaned_static_template_2025-05-28.csv
# Procesando día 2025-05-29…
#   → guardado: processed_by_date/cleaned_static_template_2025-05-29.pkl y processed_by_date/cleaned_static_template_2025-05-29.csv
# Procesando día 2025-05-30…
#   → guardado: processed_by_date/cleaned_static_template_2025-05-30.pkl y processed_by_date/cleaned_static_template_2025-05-30.csv
# Procesando día 2025-05-31…
#   → guardado: processed_by_date/cleaned_static_template_2025-05-31.pkl y processed_by_date/cleaned_static_template_2025-05-31.csv
# Procesando día 2025-06-03…
#   → guardado: processed_by_date/cleaned_static_template_2025-06-03.pkl y processed_by_date/cleaned_static_template_2025-06-03.csv
# Procesando día 2025-06-04…
#   → guardado: processed_by_date/cleaned_static_template_2025-06-04.pkl y processed_by_date/cleaned_static_template_2025-06-04.csv
# Procesando día 2025-06-06…
#   → No servicios válidos para 2025-06-06, saltando.
# Procesando día 2025-06-07…
#   → No servicios válidos para 2025-06-07, saltando.
# Procesando día 2025-06-08…
#   → No servicios válidos para 2025-06-08, saltando.
# Procesando día 2025-06-09…
#   → guardado: processed_by_date/cleaned_static_template_2025-06-09.pkl y processed_by_date/cleaned_static_template_2025-06-09.csv
# Procesando día 2025-06-12…
#   → guardado: processed_by_date/cleaned_static_template_2025-06-12.pkl y processed_by_date/cleaned_static_template_2025-06-12.csv
# Procesando día 2025-06-16…
#   → guardado: processed_by_date/cleaned_static_template_2025-06-16.pkl y processed_by_date/cleaned_static_template_2025-06-16.csv
# Procesando día 2025-07-01…
#   → guardado: processed_by_date/cleaned_static_template_2025-07-01.pkl y processed_by_date/cleaned_static_template_2025-07-01.csv
# ✅ BLOQUE 1 completado para todos los días.
