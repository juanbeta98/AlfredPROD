# %%
import pandas as pd

# %%
tables_path = "../../data/data_raw/"

address_df = pd.read_csv(tables_path + "address.csv")
cities_df = pd.read_csv(tables_path + "cities.csv")
clients_df = pd.read_csv(tables_path + "clients.csv")
service_labors_df = pd.read_csv(tables_path + "service_labors.csv")
services_df = pd.read_csv(tables_path + "services.csv")


print("Address:")
display(address_df.head())

print("Cities:")
display(cities_df.head())

print("Clients:")
display(clients_df.head())

print("Service Labors:")
display(service_labors_df.head(10))

print("Services:")
display(services_df.head(10))
# Out:
# Address:
#    address_id                                            address  name  \
# 0      147430                    Cl. 59 #56-63, Bogotá, Colombia  Casa
# 1      147429  Cl. 4 #18-251, El Poblado, Medellín, El Poblad...  Casa
# 2      147428                     Cra 40#10-12 Sur CIUDAD MONTES  casa
# 3      147427                Cra. 101 #150A 60, Bogotá, Colombia  Casa
# 4      147426                Cra. 101 #150A 60, Bogotá, Colombia  Casa
#
#                                           point  city   client  shop  alfred
# 0                 POINT (-74.0871398 4.6528474)   149  82487.0   NaN     NaN
# 1  POINT (-75.55517019999999 6.199676500000002)     1  82485.0   NaN     NaN
# 2          POINT (-74.09038559999999 4.5830756)   149      NaN   NaN     NaN
# 3          POINT (-74.09003179999999 4.7487711)   149  82288.0   NaN     NaN
# 4          POINT (-74.09003179999999 4.7487711)   149  82288.0   NaN     NaN
# Cities:
#    city                   name  \
# ...

# %%
service_labors_df[service_labors_df['service_id']==72807]
# Out:
#    service_id  labor_id  labor_type                labor_name  \
# 4       72807  126912.0        12.0  Alfred Initial Transport
# 5       72807  126913.0         3.0           Wash and Polish
# 6       72807  126914.0         2.0          Alfred Transport
#
#            labor_category  labor_price               labor_created_at  \
# 4  VEHICLE_TRANSPORTATION      35000.0  2022-11-30 11:18:02.219 -0500
# 5         WASH_AND_POLISH      20900.0  2022-11-30 11:18:02.306 -0500
# 6  VEHICLE_TRANSPORTATION      35000.0  2022-11-30 11:18:02.642 -0500
#
#                 labor_start_date                 labor_end_date  alfred   shop
# 4  2023-01-14 10:04:00.000 -0500  2023-01-14 10:48:00.000 -0500  2306.0    NaN
# 5  2023-01-14 10:48:00.000 -0500  2023-01-14 11:30:00.000 -0500     NaN  237.0
# 6  2023-01-14 11:30:00.000 -0500  2023-01-14 12:03:00.000 -0500  2306.0    NaN

# %% [markdown]
# # Directorio

# %%
directorio_df = pd.read_csv('../../data/data_pre/directorio_df.csv')

# %%
address_df[address_df['shop']==14]
# Out:
# Empty DataFrame
# Columns: [address_id, address, name, point, city, client, shop, alfred]
# Index: []

# %%
directorio_df
# Out:
#                       ALFRED'S                                  DIRECCION  \
# 0         Cesar Augusto Enciso                         Cl. 44 Sur #72u-25
# 1           Jorge Cortes Rojas                    Calle 39 sur # 72m - 26
# 2        Mauricio Gomez Pachon                         Calle 4b # 8b - 45
# 3              Orlando Jacinto                        Calle 86 # 95d - 03
# 4                 Alberto Mora                           Calle 162 #95-24
# 5          Jhon Fredy Grajales                    Carrera 147a # 142 - 30
# 6                Manuel Romero                    Carrera 93 B # 132 - 14
# 7       Yeisson Beltran Garzon                          Calle 67 # 7 - 20
# 8          Wilson Socha Cantor                      Carrera 18m # 10 - 51
# 9              Javier Barragán                     Carrera 1 #32a -20 sur
# 10           Julio Cesar Parra                      Carrera 46 # 152 - 29
# 11            Iván Darío Pinta                 Calle 96 bis # 11- 68 Este
# ...
