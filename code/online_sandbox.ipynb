# %%
import pandas as pd
import numpy as np

import ipywidgets as widgets
from ipywidgets import interact

from datetime import timedelta

from src.data_load import load_tables, load_online_instance, load_directorio_hist_df
from src.filtering import flexible_filter
from src.online_algorithms import filter_dfs_for_insertion, get_drivers
from src.metrics import collect_hist_baseline_dfs
from src.experimentation_config import *
from src.config import *
from src.distance_utils import distance

data_path = '../data'

instance = 'instRD1'
distance_method = 'haversine'

directorio_df, labors_raw_df, cities_df, duraciones_df, valid_cities = load_tables(data_path, generate_labors=False)
labors_real_df, labors_static_df, labors_dynamic_df = load_online_instance(data_path, instance, labors_raw_df)
directorio_hist_df = load_directorio_hist_df(data_path, instance)
labors_dynamic_df['latest_arrival_time'] = labors_dynamic_df['schedule_date'] + timedelta(minutes=TIEMPO_GRACIA)

# %% [markdown]
# # Upload data

# %%
import pickle

data_path = '../data'


static_upload_path = f'{data_path}/resultados/online_operation/instAD3/haversine/res_algo_ONLINE_static.pkl'
alfred_upload_path = f'{data_path}/resultados/online_operation/instAD3/haversine/res_algo_ALFRED.pkl'

with open(static_upload_path, "rb") as f:
    res = pickle.load(f)
    labors_static, moves_static, _ = res

with open(alfred_upload_path, "rb") as f:
    res = pickle.load(f)
    labors_alfred, moves_alfred, _ = res

# %%
labors_static
# Out:
#    service_id labor_id  labor_type                labor_name  \
# 0      213528   306209        12.0  Alfred Initial Transport
# 1      213531   306212        12.0  Alfred Initial Transport
# 2      213684   306372        12.0  Alfred Initial Transport
# 3      213685   306373        12.0  Alfred Initial Transport
# 4      213789   306512        12.0  Alfred Initial Transport
# ..        ...      ...         ...                       ...
# 0      273799   371190        12.0  Alfred Initial Transport
# 1      274107   371513        12.0  Alfred Initial Transport
# 2      274123   371529        12.0  Alfred Initial Transport
# 0      212724   305317        12.0  Alfred Initial Transport
# 1      213003   305612        12.0  Alfred Initial Transport
#
#             labor_category  labor_price                 labor_created_at  \
# 0   VEHICLE_TRANSPORTATION      49485.0 2025-02-17 18:00:31.525000-05:00
# 1   VEHICLE_TRANSPORTATION      49485.0 2025-02-17 18:01:41.674000-05:00
# 2   VEHICLE_TRANSPORTATION      55663.0 2025-02-18 08:47:14.194000-05:00
# 3   VEHICLE_TRANSPORTATION      55663.0 2025-02-18 08:47:47.328000-05:00
# 4   VEHICLE_TRANSPORTATION      55663.0 2025-02-18 13:12:30.573000-05:00
# ..                     ...          ...                              ...
# 0   VEHICLE_TRANSPORTATION      52988.0 2025-07-25 08:35:24.089000-05:00
# 1   VEHICLE_TRANSPORTATION      77988.0 2025-07-25 15:47:35.275000-05:00
# 2   VEHICLE_TRANSPORTATION      77988.0 2025-07-25 16:15:52.626000-05:00
# 0   VEHICLE_TRANSPORTATION      57789.0 2025-02-14 14:54:29.613000-05:00
# 1   VEHICLE_TRANSPORTATION     140000.0 2025-02-15 11:49:58.191000-05:00
#
#             labor_start_date            labor_end_date alfred  ...  \
# 0  2026-01-05 06:24:00-05:00 2026-01-05 08:32:00-05:00  10491  ...
# 1  2026-01-05 11:17:00-05:00 2026-01-05 12:04:00-05:00  70424  ...
# 2  2026-01-05 08:30:00-05:00 2026-01-05 09:55:00-05:00   5455  ...
# 3  2026-01-05 13:53:00-05:00 2026-01-05 15:25:00-05:00   9258  ...
# 4  2026-01-05 12:06:00-05:00 2026-01-05 14:10:00-05:00   2036  ...
# ..                       ...                       ...    ...  ...
# 0  2026-01-10 08:59:00-05:00 2026-01-10 09:51:00-05:00   6412  ...
# 1  2026-01-10 07:10:00-05:00 2026-01-10 08:37:00-05:00   6412  ...
# 2  2026-01-10 11:58:00-05:00 2026-01-10 13:09:00-05:00   6412  ...
# 0  2026-01-11 07:51:00-05:00 2026-01-11 09:17:00-05:00   6412  ...
# 1  2026-01-11 10:28:00-05:00 2026-01-11 11:44:00-05:00   6412  ...
#
#     address_name labor_sequence        date  \
# 0           casa              0  2026-01-05
# 1           Casa              0  2026-01-05
# 2           Casa              0  2026-01-05
# 3           Casa              0  2026-01-05
# 4    Apartamento              0  2026-01-05
# ..           ...            ...         ...
# 0    Apartamento              0  2026-01-10
# 1    Apartamento              0  2026-01-10
# 2    Apartamento              0  2026-01-10
# 0    Apartamento              0  2026-01-11
# 1    Apartamento              0  2026-01-11
#
#                                  map_start_point  \
# 0   POINT (-75.60538880000001 6.219244199999999)
# 1          POINT (-75.5758147 6.215559700000001)
# 2                   POINT (-75.566165 6.2040905)
# 3                  POINT (-75.5717425 6.2393756)
# 4                  POINT (-75.5591359 6.1836269)
# ..                                           ...
# 0          POINT (-73.1053151 7.064247200000001)
# 1          POINT (-73.0833892 7.027566699999999)
# 2   POINT (-73.11349229999999 7.108438599999999)
# 0           POINT (-73.14106249999999 7.0910625)
# 1            POINT (-73.05399799999999 6.991539)
#
#                                    map_end_point assigned_driver  \
# 0          POINT (-75.5758147 6.215559700000001)           10491
# 1   POINT (-75.60538880000001 6.219244199999999)            9258
# 2                  POINT (-75.5717425 6.2393756)            2036
# 3                   POINT (-75.566165 6.2040905)            2036
# 4          POINT (-75.5814053 6.214877200000001)           70424
# ..                                           ...             ...
# 0          POINT (-73.1134367 7.108255400000001)            6412
# 1   POINT (-73.11349229999999 7.108438599999999)            6412
# 2          POINT (-73.0833892 7.027566699999999)            6412
# 0          POINT (-73.1203002 7.126463299999999)            6412
# 1          POINT (-73.1524725 7.083261500000001)            6412
#
#                 actual_start                       actual_end    dist_km  \
# 0  2026-01-05 06:30:00-05:00 2026-01-05 07:19:56.524757-05:00   3.294720
# 1  2026-01-05 11:30:00-05:00 2026-01-05 12:19:56.524757-05:00   3.294720
# 2  2026-01-05 08:31:00-05:00 2026-01-05 09:21:57.450259-05:00   3.971670
# 3  2026-01-05 14:00:00-05:00 2026-01-05 14:50:57.450259-05:00   3.971670
# 4  2026-01-05 12:30:00-05:00 2026-01-05 13:21:23.267275-05:00   4.258525
# ..                       ...                              ...        ...
# 0  2026-01-10 09:00:00-05:00 2026-01-10 09:52:27.738681-05:00   4.974874
# 1  2026-01-10 07:00:00-05:00 2026-01-10 07:59:22.783759-05:00   9.586486
# 2  2026-01-10 12:00:00-05:00 2026-01-10 12:59:22.783759-05:00   9.586486
# 0  2026-01-11 07:30:00-05:00 2026-01-11 08:21:49.904861-05:00   4.554498
# 1  2026-01-11 10:00:00-05:00 2026-01-11 11:07:21.334979-05:00  14.903722
#
#    actual_status
# 0      COMPLETED
# 1      COMPLETED
# 2      COMPLETED
# 3      COMPLETED
# 4      COMPLETED
# ..           ...
# 0      COMPLETED
# 1      COMPLETED
# 2      COMPLETED
# 0      COMPLETED
# 1      COMPLETED
#
# [691 rows x 33 columns]

# %%
len(labors_alfred)
# Out:
# 691

# %%
len(labors_alfred['labor_id'].unique())
# Out:
# 691

# %%
hist_inst = f'{instance[:5]}S{instance[6:]}'
labors_hist_df, moves_hist_df = collect_hist_baseline_dfs(data_path, hist_inst, fechas, distance_method)

# %%
valid_cities
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 valid_cities
#
# NameError: name 'valid_cities' is not defined

# %%
import pickle
import os

metrics = ['hybrid']
alphas = [0]

def collect_alpha_results_to_df(data_path: str, instance: str, dist_method: str, metrics: list, alphas: list):
    labors_algo_df = pd.DataFrame()
    moves_algo_df = pd.DataFrame()

    for metric in metrics: 
        for alpha in alphas:
            upload_path = f'{data_path}/resultados/online_operation/{instance}/{dist_method}/res_{metric}_static.pkl'

            if not os.path.exists(upload_path):
                continue
            with open(upload_path, "rb") as f:
                res = pickle.load(f)
                inc_values, duration, results_df, moves_df, metrics_df = res

            if not results_df.empty:
                results_df = results_df.sort_values(["city", "date", "service_id", "labor_id"])
            if not moves_df.empty:
                moves_df = moves_df.sort_values(["city", "date", "service_id", "labor_id"])

            # Normalize datetime columns to Bogotá tz
            datetime_cols = [
                "labor_created_at",
                "labor_start_date",
                "labor_end_date",
                "created_at",
                "schedule_date",
                "actual_start", 
                "actual_end"
                ]


            for df in (results_df, moves_df):
                for col in datetime_cols:
                    if col in df.columns:
                        df[col] = (
                            pd.to_datetime(df[col], errors="coerce", utc=True)
                            .dt.tz_convert("America/Bogota")
                        )
                for col in ['city', 'alfred', 'service_id', 'assigned_driver']:
                    if col in df.columns:
                        df[col] = (
                            df[col]
                            .apply(lambda x: '' if (pd.isna(x) or x=='') else str(int(float(x))))
                        )

            results_df['labor_id'] = (
                results_df['labor_id']
                .apply(lambda x: '' if pd.isna(x) else str(int(float(x))))
            )

            labors_algo_df = pd.concat([labors_algo_df,results_df])
            moves_algo_df = pd.concat([moves_algo_df,moves_df])
    
    return labors_algo_df, moves_algo_df

labors_algo_static_df, moves_algo_static_df = collect_alpha_results_to_df(data_path, instance, 'haversine', metrics, alphas)

# %% [markdown]
# # Control example

# %%
labors_algo_static_df.columns
# Out:
# Index(['service_id', 'labor_id', 'labor_type', 'labor_name', 'labor_category',
#        'labor_price', 'labor_created_at', 'labor_start_date', 'labor_end_date',
#        'alfred', 'shop', 'created_at', 'schedule_date', 'client_type',
#        'paying_customer', 'state_service', 'start_address_id',
#        'start_address_point', 'end_address_id', 'end_address_point', 'city',
#        'address_id', 'address_point', 'address_name', 'map_start_point',
#        'map_end_point', 'assigned_driver', 'actual_start', 'actual_end',
#        'dist_km', 'date', 'n_drivers'],
#       dtype='object')

# %%
moves_algo_static_df.columns
# Out:
# Index(['service_id', 'labor_id', 'labor_context_id', 'labor_name',
#        'labor_category', 'assigned_driver', 'schedule_date', 'actual_start',
#        'actual_end', 'start_point', 'end_point', 'distance_km', 'duration_min',
#        'city', 'date'],
#       dtype='object')

# %%
city = '149'
date = '2026-01-08'

# %%
used_drivers = flexible_filter(labors_algo_static_df,
                city=city,
                schedule_date=date)['assigned_driver'].unique().tolist()

possible_drivers = flexible_filter(directorio_hist_df,
                city=city,
                date=date)['alfred'].unique().tolist()

# %%
unused_drivers = [i for i in possible_drivers if i not in used_drivers]
unused_drivers
# Out:
# ['10449', '10500', '11714', '11988', '2331', '69861', '70431']

# %%
labors_dynamic_filtered_df = flexible_filter(
    labors_dynamic_df,
    city=city,
    schedule_date=date)

# %% [markdown]
# ### Nuevo servicio llega a las 7:52 a.m. para las 10:30 a.m. En este caso es una sola labor de transporte.

# %%
new_service = labors_dynamic_filtered_df.iloc[0,:]

# %%
print(f'service_id: \t{new_service["service_id"]}')
print(f'labor_id: \t{new_service["labor_id"]}')
print(f'created_at: \t{new_service["created_at"].time()}')
print(f'schedule_date: \t{new_service["schedule_date"].time()}')
# print(f': {new_service[""]}')
# print(f': {new_service[""]}')
# print(f': {new_service[""]}')
# Out:
# service_id: 	254688
# labor_id: 	350824
# created_at: 	07:52:33.675000
# schedule_date: 	10:30:00

# %% [markdown]
# ### Tomar un conductor y revisar sus labores

# %%
drivers = get_drivers(
            labors_algo_df=labors_algo_static_df,
            directorio_hist_df=directorio_hist_df,
            city=city,
            fecha=date,
            get_all=True)

driver = drivers[6]
print(f'Driver: {driver}')
# Out:
# Driver: 14671

# %%
df = flexible_filter(moves_algo_static_df,
                city='149',
                schedule_date='2026-01-08',
                assigned_driver=driver).sort_values(['schedule_date', 'actual_start'])
df[['labor_context_id', 'schedule_date', 'actual_start', 'actual_end', 'start_point', 'end_point']]
# Out:
#     labor_context_id             schedule_date  \
# 891      349568_free 2026-01-08 16:30:00-05:00
# 892      349568_move 2026-01-08 16:30:00-05:00
# 893     349568_labor 2026-01-08 16:30:00-05:00
#
#                         actual_start                       actual_end  \
# 891        2026-01-08 09:00:00-05:00 2026-01-08 15:48:34.777186-05:00
# 892 2026-01-08 15:48:34.777186-05:00        2026-01-08 16:00:00-05:00
# 893        2026-01-08 16:00:00-05:00 2026-01-08 16:50:12.898351-05:00
#
#                        start_point                      end_point
# 891  POINT (-74.1122312 4.7384985)  POINT (-74.1122312 4.7384985)
# 892  POINT (-74.1122312 4.7384985)    POINT (-74.065413 4.759951)
# 893    POINT (-74.065413 4.759951)  POINT (-74.0588765 4.7905312)

# %%
labors_driver_df, moves_driver_df = filter_dfs_for_insertion(
    labors_algo_static_df, 
    moves_algo_static_df,
    city=city,
    fecha=date,
    created_at=new_service['created_at'],
    driver=driver
)

order = ['labor_id','labor_context_id','schedule_date', 'actual_start', 'actual_end', 'start_point', 'end_point']
order += [j for j in moves_driver_df.columns.tolist() if j not in order]
display(labors_driver_df)
display(moves_driver_df[order])
# Out:
#   service_id labor_id  labor_type                labor_name  \
# 0     253543   349568        12.0  Alfred Initial Transport
#
#            labor_category  labor_price                 labor_created_at  \
# 0  VEHICLE_TRANSPORTATION      55663.0 2025-06-11 09:13:52.347000-05:00
#
#            labor_start_date            labor_end_date alfred  ...  \
# 0 2026-01-08 16:36:00-05:00 2026-01-08 20:13:00-05:00   5832  ...
#
#                            address_point address_name  \
# 0  POINT (-74.0805306 4.755374499999999)         casa
#
#                map_start_point                  map_end_point  \
# 0  POINT (-74.065413 4.759951)  POINT (-74.0588765 4.7905312)
#
#    assigned_driver              actual_start                       actual_end  \
# 0            14671 2026-01-08 16:00:00-05:00 2026-01-08 16:50:12.898351-05:00
#
#     dist_km        date n_drivers
# 0  3.476648  2026-01-08        19
#
# [1 rows x 32 columns]
#   labor_id labor_context_id             schedule_date  \
# 0   349568      349568_free 2026-01-08 16:30:00-05:00
# 1   349568      349568_move 2026-01-08 16:30:00-05:00
# 2   349568     349568_labor 2026-01-08 16:30:00-05:00
#
#                       actual_start                       actual_end  \
# 0        2026-01-08 09:00:00-05:00 2026-01-08 15:48:34.777186-05:00
# 1 2026-01-08 15:48:34.777186-05:00        2026-01-08 16:00:00-05:00
# 2        2026-01-08 16:00:00-05:00 2026-01-08 16:50:12.898351-05:00
#
#                      start_point                      end_point service_id  \
# 0  POINT (-74.1122312 4.7384985)  POINT (-74.1122312 4.7384985)     253543
# 1  POINT (-74.1122312 4.7384985)    POINT (-74.065413 4.759951)     253543
# 2    POINT (-74.065413 4.759951)  POINT (-74.0588765 4.7905312)     253543
#
#                  labor_name          labor_category assigned_driver  \
# 0                 FREE_TIME               FREE_TIME           14671
# 1               DRIVER_MOVE             DRIVER_MOVE           14671
# 2  Alfred Initial Transport  VEHICLE_TRANSPORTATION           14671
#
#    distance_km  duration_min city        date
# 0      0.00000         408.6  149  2026-01-08
# 1      5.71019          11.4  149  2026-01-08
# 2          NaN          50.2  149  2026-01-08

# %%
labor_iter = 0

# first_labor = labors_driver_df.iloc[labor_iter,:]

available_from = moves_driver_df['end_point'][labor_iter]
available_at = moves_driver_df['actual_end'][labor_iter]

available_from, available_at
# Out:
# ('POINT (-74.0286017 4.9203296)',
#  Timestamp('2026-01-08 09:42:38.635063-0500', tz='America/Bogota'))

# %%
next_service_start_pos = moves_driver_df['start_point'][labor_iter+3]
next_service_start_time = moves_driver_df['schedule_date'][labor_iter+3]

next_service_start_pos, next_service_start_time
# Out:
# ('POINT (-74.0434496 4.703822299999999)',
#  Timestamp('2026-01-08 09:00:00-0500', tz='America/Bogota'))

# %%
next_service_start_time <= new_service['schedule_date']
# Out:
# True

# %% [markdown]
# ### Since the starting time of the next service is earlier than the schedule time of the new service, it is not

# %%
labor_iter += 3

# %%
# first_labor = labors_driver_df.iloc[labor_iter,:]

available_from = moves_driver_df['end_point'][labor_iter]
available_at = moves_driver_df['actual_end'][labor_iter]

available_from, available_at
# Out:
# ('POINT (-74.028923 4.704466)',
#  Timestamp('2026-01-08 09:17:25.029013-0500', tz='America/Bogota'))

# %%
next_service_start_pos = moves_driver_df['start_point'][labor_iter+3]
next_service_start_time = moves_driver_df['schedule_date'][labor_iter+3]

next_service_start_pos, next_service_start_time
# Out:
# ('POINT (-74.0343054 4.692379399999999)',
#  Timestamp('2026-01-08 10:00:00-0500', tz='America/Bogota'))

# %%
next_service_start_time <= new_service['schedule_date']
# Out:
# True

# %% [markdown]
# ### Since the starting time of the next service is earlier than the schedule time of the new service, it is not

# %%
labor_iter += 3

# %%
# first_labor = labors_driver_df.iloc[labor_iter,:]

available_from = moves_driver_df['end_point'][labor_iter]
available_at = moves_driver_df['actual_end'][labor_iter]

available_from, available_at
# Out:
# ('POINT (-74.06596379999999 4.6401052)',
#  Timestamp('2026-01-08 10:25:11.051557-0500', tz='America/Bogota'))

# %%
next_service_start_pos = moves_driver_df['start_point'][labor_iter+3]
next_service_start_time = moves_driver_df['schedule_date'][labor_iter+3]

next_service_start_pos, next_service_start_time
# Out:
# ('POINT (-74.10500789999999 4.6304576)',
#  Timestamp('2026-01-08 14:00:00-0500', tz='America/Bogota'))

# %%
next_service_start_time <= new_service['schedule_date']
# Out:
# False

# %% [markdown]
# ### This is the breaking point... this means that the next labor of the driver is after the scheduled time of the new labor. This is the point where we could potentially assign the new labor.
#
# ### Now it's needed to check if the driver could make it from it's current position to the new service

# %%
distance_to_new_service, _ = distance(available_from, 
                                   new_service['start_address_point'],
                                   method='haversine')
travel_time = distance_to_new_service/ALFRED_SPEED*60

would_arrive_at = available_at + timedelta(minutes=travel_time)

# %%
would_arrive_at <= new_service['latest_arrival_time']
# Out:
# True

# %% [markdown]
# ### The driver would be able to arrive to the service in time. Time to simulate the assignment and make sure he would arrive on time to the next service

# %%
new_service_travel_distance, _ = distance(new_service['start_address_point'],
                                       new_service['end_address_point'], 'haversine')

new_service_travel_time = new_service_travel_distance/VEHICLE_TRANSPORT_SPEED*60

total_new_service_duration = TIEMPO_ALISTAR + new_service_travel_time + TIEMPO_FINALIZACION

finish_new_service_time = would_arrive_at + timedelta(minutes=total_new_service_duration)
finish_new_service_pos = new_service['end_address_point']

# %%
finish_new_service_time
# Out:
# Timestamp('2026-01-08 11:23:01.646585-0500', tz='America/Bogota')

# %% [markdown]
# #### Compute driving time to the next scheduled_service

# %%
travel_distance_to_next_service, _ = distance(finish_new_service_pos, 
                                              next_service_start_pos,
                                              'haversine')
travel_time_to_next_service = travel_distance_to_next_service/ALFRED_SPEED*60
would_arrive_to_next_service_at = finish_new_service_time + timedelta(minutes=travel_distance_to_next_service)

# %%
would_arrive_to_next_service_at <= next_service_start_time + timedelta(minutes=TIEMPO_GRACIA)
# Out:
# True

# %%
### LOGICA COMPLETA
